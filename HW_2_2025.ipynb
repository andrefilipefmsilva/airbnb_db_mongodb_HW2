# %% [markdown]
# <font size="8">Homework 2: AirBnB Document Database</font>
#
# Group number: `1`
#
# Group members:
# 1. `Afonso Ascensão : 20240684`
# 2. `André Filipe Silva : 20230972`
# 3. `Joana Esteves : 20240746`
# 4. `Susana Reis : 20240567`
# 5. `Tomás Figueiredo : 20240941`
#
# The Homework 2 is comprised of two parts:
# 1. Data modelling (15 points).
# 2. Queries to database to answer the questions (25 points).

# %% [markdown]
# <font size="6">1. Data Modelling</font>
#
# <font size="4">Congratulations! You’ve been hired as part of the new Data Engineering and Management team in the AirBNB Business Intelligence department. The company is restructuring due to unsatisfactory performance from the previous teams.
#
# Before leaving, the head of the Data Modelling department highlighted several issues:
#
# **Data Storage**: A lot of data about AirBNB listings is stored in a single document. While this approach has some advantages, it has also caused performance issues. Queries are slow, and the team didn’t apply patterns, which could improve performance by optimizing the data model. Indexes were also not used.
#
# **Reviews Growth**: The number of reviews for AirBNB is growing rapidly. Currently, we overwrite reviews regularly, but the Business Intelligence department will benefit from storing all reviews and analyzing them over time.
#
# **Data Errors**: There are errors in the data collection, such as duplicate data entries and incorrect timestamps for transactions. The new team will need to decide how to fix these issues.
#
# **Your Role**: In your new role, you’ll need to consider how each database query is used, how often it is needed, and its impact on reads and writes. You should update the database schema to optimize for business use cases. Use tools like embedding, linking, indexes, and patterns to improve the data model. You may need to create new fields, documents, or collections. Be sure to document the pattern you’re applying and the reasons behind your decisions, especially when dealing with duplication and risks of outdated data.
#
# **Key tasks include**:
#
# 1. Streamlining the data collection process.
# 2. Cleaning up the data and optimizing what will be returned for each use case.
# 3. Applying the correct patterns to speed up common queries.
# 4. Ensuring departments get accurate and relevant information from the database.
# 5. Sharing the updated data model schema with other departments.
#
# **Good Practices**: [Check Chapter 6, Mastering MongoDB]
#
# 1. All newly created fields should have capitalized names.
# 2. New queries should work with the most up-to-date database version. If you make multiple changes, all queries should still work after the final updates.
# 3. For some queries, you may need to change the database schema.
# 4. When you are applying specific patterns, like polymorphic, subset, or bucket, name them accordingly.
# 5. Document each major transformation using this format:
# *“We applied {transformation name} because {reasoning behind it}. We expect {change/result} based on {observable measure, such as query speed, number of documents returned, index use, etc.}.”*
#
# </font>

# %% [markdown]
# ## **Joana + Tomás**

# %% [markdown]
# **Data Cleanup and Schema Adjustments:** [9 points in total]
#
# 1) Before working on the queries below, review the data and adjust the schema based on the typical use case described.
#
# **Typical Use Case**: The most common use of the database is to show property listing information to customers. A query retrieves a listing document from the database. Currently, retrieving a listing takes too long. Decide what information should be included in a typical query and optimize the structure accordingly. For example, customers usually only need a sample of reviews, not all reviews (even though all reviews are stored). They also don’t need past transaction data. Update the document schema to fit this use case. This might involve creating new collections or documents.
#
# **Data Cleanup**: Review the data for any errors (such as transactions that don’t belong to the listing) or unnecessary duplication, and clean it up where needed.

# %% [markdown]
# <font size="6">2. Uses for the database</font>
#
# <font size="4">Different AirBNB departments require different analytics from our common database.
# Below are the specific questions from various departments:
#
# **Standard Difficulty Questions:** [2 points per question]
#
# ## **Susana**
# 2)	Once a month, we reward hosts with recognition. Select three superhosts with at least two listings that can accommodate more than four people.
#
# ## **Susana**
# 3)	The company considers inevsting into property to rent. Which bed type is most common in listings with a waterfront and a dishwasher in New York?
#
# ## **Susana**
# 4)	We're considering hiring someone to write reviews professionally. Who wrote the longest review in New York?
#
# ## **Susana**
# 5)	To assess the security of different areas, what is the biggest and smallest (price-security deposit) difference per number of visitors at a property?
#
# ## **André**
# 6)  Identify areas by whether they are typically used for short breaks, like weekend mini breaks, or whether they are more suitable for long trips. This information support targeted advertising of different customer types. It is not expected to change much over time so we won’t look to update it, we just require current view. What is the average duration of stay (in nights) per type of property per city (you can use the maximum_nights to measure length of stays)? For each property type return the city with the highest and lowest average value.
#
# **Advanced Difficulty Questions (Consider database optimization for these queries):** [3 points per question]
#
# ## **Afonso**
# 7)	We are creating a new webpage for hosts when setting up their account. It will list suggested typical amenities. This data will need to be available every time a host registers a property but is not expected to change very much. The starting point for the list will be all unique amenities currently listed in properties (across all documents). Optimise the database for this use case and show how the data should be queried.
#
# ## **Afonso**
# 8)	We plan to rtack our reviewers better. We want to create a webpage that shows the top 20 reviewers and the count of the number of reviews of each of these reviewers. This webpage should be kept up to date. It should also have a link to return the number of reviews for a given reviewer ID or Name (show how to query for number of reviews by ID or query quickly).
#
# ## **André**
# 9)	For each property we store review scores across different metrics (accuracy, check-in, cleanliness etc). We consider adding more metrics, although there is no clarity on what these will be. We want to be able to easily query the average score across all of these metrics, including any new metrics that might be added without changing the query. Adjust the data model so this can be done and show the query for an example property.
#
# ## **André**
# 10)	We aim to have better access to information about transaction, we wish to develop a search engine that can calculate the average value of transactions in a given period of time quickly for a given property.
#
# ## **André**
# 11)	We wish to have a summary webpage that displays information about our top destinations. This webpage should display for each of the top 10 cities some basic information about our operations in the area (number of properties by type for example, average price by type) but you can choose the metrics. For each of the top 10 cities it should also provide some basic information about the top 3 properties in each city (price, number of review, whatever you think useful) to show an example of the properties available in the area. We would like to keep this webpage up to date as information changes.
#
# **Database updates:** [2 points per question]
# ## **Joana + Tomás**
# After optimizing the database, show how to complete the following updates. You can create fictional data. Ensure that previous data does not become stale:
#
# 12) Add a new property with a new host in one of the top 10 cities. The host selects the top 10 most common amenities to list.
#
# 13) Add a new review from one of our top 20 reviewers for this new property.
#
# 14) Add a new review metric called 'x_factor' with a score of 10. Show that the average score across all metrics is correctly calculated for this listing, using the previously developed query.

# %% [markdown]
# # Setup
#
# 1. run Jupyter
# 2. run Docker
# 3. create MongoDB container in Command Prompt: make sure you don't have 'leftover' container from previous runs
#
#         docker run --name mongodb -d -e MONGO_INITDB_ROOT_USERNAME=AzureDiamond -e MONGO_INITDB_ROOT_PASSWORD=hunter2 -p 27017:27017 mongo
#
# 4. run Studio3T
#
# 5. create New Connection OR reconnect to existing Connection:
#
#     5.A	In Studio3T create Connection:
#             a.	Press Connection -> New Connection
#             b.	Insert credentials into URI field: mongodb://AzureDiamond:hunter2@localhost:27017
#             c.	Press Test Connection
#             d.	Assign a name to the Connection (top empty line) -> Save
#             e.	Press Connect
#
#     5.B In Studio3T reconnect to Connection:
#             a. press Connect (top left corner)
#             b. choose MongoDB connection  -> press Connect (MongoDB container must be runnning by this time)
#
# 6.	In Studio3T import the Database:
#             a.	Press Import
#             b.	Choose BSON mongodump archive
#             c.	Find your database path
#             d.	Select All file formats and choose the database file ‘sampledata.archive’
#             e.	Press Run: be patient while the database loads
#             f.	Inspect the collections and documents
#
# Done!

# %%
# Python Connector

# !pip install pymongo
# or #!conda install -y pymongo

from datetime import datetime
from pprint import pprint
import time
from bson.objectid import ObjectId

from pymongo import MongoClient

user="AzureDiamond"
password="hunter2"
host="localhost"
port="27017"
protocol="mongodb"

client = MongoClient(f"{protocol}://{user}:{password}@{host}:{port}")

# Database check
db = client.sample_airbnb 
print(f"Database info: {db}\n")
db.name
# Out:
# Requirement already satisfied: pymongo in /Users/susanazreis/.pyenv/versions/3.11.6/lib/python3.11/site-packages (4.11.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/susanazreis/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pymongo) (2.7.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Database info: Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sample_airbnb')
# 'sample_airbnb'

# %% [markdown]
# # Loading and Inspecting database

# %%
# Collections are inside our Database 'sample_analytics'

collection_list = db.list_collection_names()
print(f"The database contains {len(collection_list)} collections")
print(f"All collections: {collection_list[0:]}")
print(f"Collection {collection_list[0]} contains {db[collection_list[0]].count_documents({})} documents")
# Out:
# The database contains 2 collections
# All collections: ['listingsAndReviews', 'listingsAndReviews_new']
# Collection listingsAndReviews contains 5555 documents

# %% [markdown]
# [PyMongo documentation](https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html)

# %% [markdown]
# ### Question 1

# %% [markdown]
# ### Question 2 - Once a month, we reward hosts with recognition. Select three superhosts with at least two listings that can accommodate more than four people.

# %%
pipeline = list(
    db.listingsAndReviews.aggregate([
        {"$match": { 
            "host.host_is_superhost": True,
            "accommodates": { "$gt": 4 }
        }},
        {"$group": { 
            "_id": "$host.host_id", 
            "host_name": { "$first": "$host.host_name" }, 
            "host_listings_count": { "$sum": 1 }
        }},
        {"$match": { 
            "host_listings_count": { "$gte": 2 } 
        }},
        {"$sort": { "host_listings_count": -1 }}, 
        {"$limit": 3}
    ])
)

print("\nSelected Superhosts:\n")
for doc in pipeline:
    pprint(doc)
# Out:
# Selected Superhosts:
#
# {'_id': '42618840',
#  'host_listings_count': 3,
#  'host_name': 'Great Vacation Retreats'}
# {'_id': '10496350', 'host_listings_count': 3, 'host_name': 'Elite'}
# {'_id': '36133410', 'host_listings_count': 3, 'host_name': 'Patty And Beckett'}

# %% [markdown]
# ### Question 3 - The company considers investing into property to rent. Which bed type is most common in listings with a waterfront and a dishwasher in New York?

# %%
pipeline = list(
    db.listingsAndReviews.aggregate([
        {"$match": { 
            "address.market": "New York",
            "amenities": {"$in": ["Dishwasher", "Waterfront"]},
        }},
        {"$group": {
            "_id": "$bed_type", 
            "count": {"$sum": 1}
        }},
        {"$sort": {"count": -1}},
        {"$limit": 1}
    ])
)

for doc in pipeline:
    pprint(doc)
# Out:
# {'_id': 'Real Bed', 'count': 75}

# %% [markdown]
# ### Question 4 - We're considering hiring someone to write reviews professionally. Who wrote the longest review in New York?

# %%
pipeline = list(
    db.listingsAndReviews.aggregate([
        {"$match": { 
            "address.market": "New York", 
            "reviews": { "$exists": True } 
        }},
        {"$unwind": "$reviews"},
        {"$sort": { "reviews.comments": -1 }}, 
        {"$project": { 
            "reviews.reviewer_name": 1,
            "reviews.comments": 1
        }},
        {"$limit": 1}
    ])
)

print("\nPerson with the Longest Review in New York:\n")
for doc in pipeline:
    pprint(doc)
# Out:
# Person with the Longest Review in New York:
#
# {'_id': '14569881',
#  'reviews': {'comments': 'ﾙｰﾑｵｰﾅｰは非常に日本贔屓のｱﾒﾘｶ人で､部屋はﾃﾞｻﾞｲﾝのｱｲﾃﾞｨｱに富み､清潔で､静かで､ﾘﾗｯｸｽできます｡\n'
#                          'ﾙｰﾑﾒｲﾄも皆優しくて親切です｡\n'
#                          '泊まった部屋は､大きなｽﾀｼﾞｵの中に手作りで創られた2階建ての小屋の1階でした｡工夫と創造性に溢れた､素敵な空間です｡wifiもあります｡\n'
#                          'ただ､もし一般的ﾋﾞｼﾞﾈｽﾕｰｽで考えるなら､この部屋に限らず､一般的なｼｪｱﾙｰﾑは避けたほうがいいでしょう｡日本人はなんだかんだで､仕事に集中したい時は完全に遮蔽されたﾌﾟﾗｲﾍﾞｰﾄ空間を好みます(僕もそう)が､ｼｪｱﾙｰﾑでそれは無理です｡静かとは言え､3人が共同生活をしているので､会話は発生するし､料理や掃除も始まるし､風呂の順番だってﾏﾅｰを守らねばなりません｡あくまでくつろぐときに部屋を利用し､仕事はｶﾌｪなどでやるのが無難です｡\n'
#                          'ちなみに､ｵｰﾅｰは日本語を話せますが､少しだけです｡基本的に英語でｺﾐｭﾆｹｰｼｮﾝする必要があります｡\n'
#                          'ちなみにｱﾒﾆﾃｨはﾊﾞｽﾀｵﾙ1枚なので､歯ﾌﾞﾗｼや石鹸など身の回りのものは自分で持っていくか近所のﾃﾞﾘなどで買いましょう｡\n'
#                          'よい旅を｡',
#              'reviewer_name': 'Kazu'}}

# %% [markdown]
# ### Question 5 - To assess the security of different areas, what is the biggest and smallest (price-security deposit) difference per number of visitors at a property?

# %%
pipeline = list(
    db.listingsAndReviews.aggregate([
        {"$match": {
            "price": {"$exists": True},
            "security_deposit": {"$exists": True}  
        }},

        {"$project": {
            "difference": {"$subtract": ["$price", "$security_deposit"]} 
        }},
        {"$group": {
            "_id": None, 
            "max_difference": {"$max": "$difference"}, 
            "min_difference": {"$min": "$difference"}
        }}
    ])
)

print("\nBiggest and Smallest Price-Security Deposit Differences:\n")
for doc in pipeline:
    pprint(doc)
# Out:
# Biggest and Smallest Price-Security Deposit Differences:
#
# {'_id': None,
#  'max_difference': Decimal128('8501.00'),
#  'min_difference': Decimal128('-38459.00')}

# %%
#mesma coisa mas a retornar os ID's 
pipeline = list(
    db.listingsAndReviews.aggregate([
        {"$match": {
            "price": {"$exists": True},  
            "security_deposit": {"$exists": True}  
        }},
        {"$project": {
            "_id": 1,  
            "price": {"$toDouble": "$price"},  
            "security_deposit": {"$toDouble": "$security_deposit"},  
            "difference": {"$subtract": [{"$toDouble": "$price"}, {"$toDouble": "$security_deposit"}]}  
        }},
        {"$sort": {"difference": 1}}, 
        {"$group": {
            "_id": None,  
            "max_difference": {"$last": "$difference"},  
            "max_id": {"$last": "$_id"},
            "min_difference": {"$first": "$difference"},  
            "min_id": {"$first": "$_id"} 
        }}
    ])
)

print("\nBiggest and Smallest Price-Security Deposit Differences:\n")
for doc in pipeline:
    pprint(doc)
# Out:
# Biggest and Smallest Price-Security Deposit Differences:
#
# {'_id': None,
#  'max_difference': 8501.0,
#  'max_id': '22200454',
#  'min_difference': -38459.0,
#  'min_id': '2688143'}

# %%
#para ver a db. Depois apagar.
document = db.listingsAndReviews.find({"_id": "2688143"})

print("\nDocument for _id = 22200454:\n")
for doc in document:
    pprint(doc)
# Out:
# Document for _id = 22200454:
#
# {'_id': '2688143',
#  'access': '',
#  'accommodates': 2,
#  'address': {'country': 'Hong Kong',
#              'country_code': 'HK',
#              'government_area': 'Eastern',
#              'location': {'coordinates': [114.19337, 22.28558],
#                           'is_location_exact': True,
#                           'type': 'Point'},
#              'market': 'Hong Kong',
#              'street': 'Hong Kong, Hong Kong Island, Hong Kong',
#              'suburb': 'Eastern District'},
#  'amenities': ['TV',
#                'Internet',
#                'Wifi',
#                'Air conditioning',
#                'Kitchen',
#                'Paid parking off premises',
#                'Elevator',
#                'Washer',
#                'Dryer',
#                'Hangers',
#                'Hair dryer',
#                'Iron',
#                'Laptop friendly workspace',
#                'Room-darkening shades',
#                'Hot water',
#                'Bed linens',
#                'Ethernet connection',
#                'Microwave',
#                'Refrigerator',
#                'Dishes and silverware',
#                'Cooking basics',
#                'Long term stays allowed',
#                'Host greets you'],
#  'availability': {'availability_30': 0,
#                   'availability_365': 169,
#                   'availability_60': 0,
#                   'availability_90': 0},
#  'bathrooms': Decimal128('1.0'),
#  'bed_type': 'Real Bed',
#  'bedrooms': 1,
#  'beds': 1,
#  'calendar_last_scraped': datetime.datetime(2019, 3, 11, 4, 0),
#  'cancellation_policy': 'moderate',
#  'cleaning_fee': Decimal128('0.00'),
#  'description': '1) Affordable stylish studio apartment located at Tin Hau '
#                 '(Very close to Causeway Bay); 2) 5 mins walking distance to '
#                 'Tin Hau MTR station; 3) Free cleaning service provided; 3) '
#                 'Numerous restaurants and shops located nearby; 4) Branded '
#                 'appliances/utilities provided in the apartment; 5) Monthly '
#                 'Rental Only *** Minimum Stay: 60 nights *** Welcome to '
#                 'LauLi15, it locates just a few steps away from Tin Hau MTR '
#                 'station and within easy walking distance to Causeway Bay’s '
#                 'luxury shopping destinations and restaurants. Just minutes by '
#                 'car or MTR from Quarry Bay and Central business district, it '
#                 'is also a short stroll across the street from Hong Kong’s '
#                 'iconic’s public park, Victoria Park. There are also choices '
#                 'of international restaurants and shops around LauLi15 and you '
#                 'will definitely find it convenient to everything and enjoy '
#                 'the local experiences for both business and leisure stay.',
#  'extra_people': Decimal128('0.00'),
#  'first_review': datetime.datetime(2014, 6, 8, 4, 0),
#  'guests_included': Decimal128('1'),
#  'host': {'host_about': 'Designer Studios',
#           'host_has_profile_pic': True,
#           'host_id': '6315448',
#           'host_identity_verified': False,
#           'host_is_superhost': True,
#           'host_listings_count': 13,
#           'host_location': 'Hong Kong',
#           'host_name': 'Lauli15',
#           'host_neighbourhood': 'Causeway Bay',
#           'host_picture_url': 'https://a0.muscache.com/im/users/6315448/profile_pic/1382599186/original.jpg?aki_policy=profile_x_medium',
#           'host_response_rate': 80,
#           'host_response_time': 'within a day',
#           'host_thumbnail_url': 'https://a0.muscache.com/im/users/6315448/profile_pic/1382599186/original.jpg?aki_policy=profile_small',
#           'host_total_listings_count': 13,
#           'host_url': 'https://www.airbnb.com/users/show/6315448',
#           'host_verifications': ['email',
#                                  'phone',
#                                  'reviews',
#                                  'jumio',
#                                  'government_id']},
#  'house_rules': 'Please note:- 1) The photos provided on Airbnb are for '
#                 'indications only; 2) For the electricity and water charges, '
#                 'we agree to pay maximum HK$500 allowance per month. Tenant '
#                 'may need to top up if exceed this amount;',
#  'images': {'medium_url': '',
#             'picture_url': 'https://a0.muscache.com/im/pictures/d66cd9ff-a435-484d-81cf-b7e2f74cc209.jpg?aki_policy=large',
#             'thumbnail_url': '',
#             'xl_picture_url': ''},
#  'interaction': '',
#  'last_review': datetime.datetime(2018, 6, 29, 4, 0),
#  'last_scraped': datetime.datetime(2019, 3, 11, 4, 0),
#  'listing_url': 'https://www.airbnb.com/rooms/2688143',
#  'maximum_nights': '365',
#  'minimum_nights': '60',
#  'name': 'Stylish Studio Apartment Near Causeway Bay [2]',
#  'neighborhood_overview': '',
#  'notes': '',
#  'number_of_reviews': 2,
#  'price': Decimal128('769.00'),
#  'property_type': 'Apartment',
#  'review_scores': {'review_scores_accuracy': 10,
#                    'review_scores_checkin': 10,
#                    'review_scores_cleanliness': 10,
#                    'review_scores_communication': 10,
#                    'review_scores_location': 10,
#                    'review_scores_rating': 100,
#                    'review_scores_value': 9},
#  'reviews': [{'_id': '13912452',
#               'comments': "The apartment was excellent, brand new, it's in a "
#                           'new annex of an older building, very well '
#                           "equipped.  It's located in Tin Hau, just 100 meters "
#                           'from the MTR station, and within walking distance '
#                           'to Causeway Bay.  There are plenty of nice '
#                           'restaurants within close proximity.  Grace was an '
#                           'excellent host.  I would highly recommend the '
#                           'apartment.',
#               'date': datetime.datetime(2014, 6, 8, 4, 0),
#               'listing_id': '2688143',
#               'reviewer_id': '388392',
#               'reviewer_name': 'Asaif'},
#              {'_id': '283017127',
#               'comments': 'Excellent experience overall. The location is '
#                           'great-3min to subway station and all kinds of local '
#                           'restaurants. The room was clean, stylish, and great '
#                           'value for long-term stay. The owner was very '
#                           'friendly and helpful. He responded to our need very '
#                           'quickly every time.',
#               'date': datetime.datetime(2018, 6, 29, 4, 0),
#               'listing_id': '2688143',
#               'reviewer_id': '9947961',
#               'reviewer_name': 'Emma'}],
#  'room_type': 'Entire home/apt',
#  'security_deposit': Decimal128('39228.00'),
#  'space': 'Welcome to LauLi15, it locates just a few steps away from Tin Hau '
#           'MTR station and within easy walking distance to Causeway Bay’s '
#           'luxury shopping destinations and restaurants. Just minutes by car '
#           'or MTR from Quarry Bay and Central business district, it is also a '
#           'short stroll across the street from Hong Kong’s iconic’s public '
#           'park, Victoria Park. There are also choices of international '
#           'restaurants and shops around LauLi15 and you will definitely find '
#           'it convenient to everything and enjoy the local experiences for '
#           'both business and leisure stay.',
#  'summary': '1) Affordable stylish studio apartment located at Tin Hau (Very '
#             'close to Causeway Bay); 2) 5 mins walking distance to Tin Hau MTR '
#             'station; 3) Free cleaning service provided; 3) Numerous '
#             'restaurants and shops located nearby; 4) Branded '
#             'appliances/utilities provided in the apartment; 5) Monthly Rental '
#             'Only *** Minimum Stay: 60 nights ***',
#  'transit': ''}

# %% [markdown]
# ### Question 6 - Identify areas by whether they are typically used for short breaks, like weekend mini breaks, or whether they are more suitable for long trips. This information support targeted advertising of different customer types. It is not expected to change much over time so we won’t look to update it, we just require current view. What is the average duration of stay (in nights) per type of property per city (you can use the maximum_nights to measure length of stays)? For each property type return the city with the highest and lowest average value.

# %%
pipeline = [
    # Ensure maximum_nights exists and is a valid number
    {"$match": {"maximum_nights": {"$exists": True, "$ne": ""}
    }},


    # Group by city and property type, calculating the average maximum_nights
    {"$group": {
        "_id": {"city": "$address.market", "property_type": "$property_type"},
        "avg_maximum_nights": {"$avg": {"$toDouble": "$maximum_nights"}}
    }},

    # Reshape the output for easier processing
    {"$project": {
        "city": "$_id.city",
        "property_type": "$_id.property_type",
        "avg_maximum_nights": 1,
        "_id": 0
    }},

    # Group by property type to find the cities with the highest and lowest average duration
    {"$group": {
        "_id": "$property_type",
        "highest_city": {"$max": {"city": "$city", "avg_nights": "$avg_maximum_nights"}},
        "lowest_city": {"$min": {"city": "$city", "avg_nights": "$avg_maximum_nights"}}
    }}
]

# Execute query
result = list(db.listingsAndReviews.aggregate(pipeline))

# Print result
for item in result:
    pprint(item)
# Out:
# {'_id': 'Boutique hotel',
#  'highest_city': {'avg_nights': 577.5, 'city': 'Sydney'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Barcelona'}}
# {'_id': 'Castle',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Montreal'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Montreal'}}
# {'_id': 'Pension (South Korea)',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Hong Kong'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Hong Kong'}}
# {'_id': 'Train',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Sydney'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Sydney'}}
# {'_id': 'Earth house',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Rio De Janeiro'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Rio De Janeiro'}}
# {'_id': 'Hut',
#  'highest_city': {'avg_nights': 30.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 30.0, 'city': 'The Big Island'}}
# {'_id': 'Condominium',
#  'highest_city': {'avg_nights': 505.04761904761904, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 30.0, 'city': ''}}
# {'_id': 'Nature lodge',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Maui'},
#  'lowest_city': {'avg_nights': 90.0, 'city': 'Istanbul'}}
# {'_id': 'Treehouse',
#  'highest_city': {'avg_nights': 30.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 30.0, 'city': 'The Big Island'}}
# {'_id': 'Bed and breakfast',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 531.625, 'city': 'Barcelona'}}
# {'_id': 'Bungalow',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 578.0, 'city': 'Maui'}}
# {'_id': 'Houseboat',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Hong Kong'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Hong Kong'}}
# {'_id': 'Aparthotel',
#  'highest_city': {'avg_nights': 212.5, 'city': 'Rio De Janeiro'},
#  'lowest_city': {'avg_nights': 780.0, 'city': 'Barcelona'}}
# {'_id': 'Heritage hotel (India)',
#  'highest_city': {'avg_nights': 14.0, 'city': 'Hong Kong'},
#  'lowest_city': {'avg_nights': 14.0, 'city': 'Hong Kong'}}
# {'_id': 'Tiny house',
#  'highest_city': {'avg_nights': 14.0, 'city': 'Sydney'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Barcelona'}}
# {'_id': 'Camper/RV',
#  'highest_city': {'avg_nights': 30.0, 'city': 'Porto'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Montreal'}}
# {'_id': 'Guesthouse',
#  'highest_city': {'avg_nights': 691.4, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 652.5, 'city': 'Barcelona'}}
# {'_id': 'House',
#  'highest_city': {'avg_nights': 621.5, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 863.125, 'city': 'Barcelona'}}
# {'_id': 'Resort',
#  'highest_city': {'avg_nights': 607.5, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 754.6666666666666, 'city': 'Kauai'}}
# {'_id': 'Barn',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'The Big Island'}}
# {'_id': 'Farm stay',
#  'highest_city': {'avg_nights': 846.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Barcelona'}}
# {'_id': 'Other',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Barcelona'}}
# {'_id': 'Boat',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Porto'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Barcelona'}}
# {'_id': 'Campsite',
#  'highest_city': {'avg_nights': 30.0, 'city': 'Oahu'},
#  'lowest_city': {'avg_nights': 30.0, 'city': 'Oahu'}}
# {'_id': 'Loft',
#  'highest_city': {'avg_nights': 28.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 607.2105263157895, 'city': 'Barcelona'}}
# {'_id': 'Hotel',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Porto'},
#  'lowest_city': {'avg_nights': 886.5555555555555, 'city': 'Hong Kong'}}
# {'_id': 'Casa particular (Cuba)',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Rio De Janeiro'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Barcelona'}}
# {'_id': 'Apartment',
#  'highest_city': {'avg_nights': 371.3636363636364, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 568.75, 'city': ''}}
# {'_id': 'Serviced apartment',
#  'highest_city': {'avg_nights': 527.8571428571429, 'city': 'Sydney'},
#  'lowest_city': {'avg_nights': 544.3181818181819, 'city': 'Barcelona'}}
# {'_id': 'Villa',
#  'highest_city': {'avg_nights': 445.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 15.0, 'city': 'Barcelona'}}
# {'_id': 'Cabin',
#  'highest_city': {'avg_nights': 906.0, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 120.0, 'city': 'Maui'}}
# {'_id': 'Guest suite',
#  'highest_city': {'avg_nights': 419.5, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Barcelona'}}
# {'_id': 'Hostel',
#  'highest_city': {'avg_nights': 10.0, 'city': 'Sydney'},
#  'lowest_city': {'avg_nights': 754.6666666666666, 'city': 'Barcelona'}}
# {'_id': 'Townhouse',
#  'highest_city': {'avg_nights': 531.8, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 30.0, 'city': ''}}
# {'_id': 'Chalet',
#  'highest_city': {'avg_nights': 1125.0, 'city': 'Sydney'},
#  'lowest_city': {'avg_nights': 30.0, 'city': 'Istanbul'}}
# {'_id': 'Cottage',
#  'highest_city': {'avg_nights': 543.4285714285714, 'city': 'The Big Island'},
#  'lowest_city': {'avg_nights': 1125.0, 'city': 'Hong Kong'}}

# %% [markdown]
# ### Question 7

# %% [markdown]
# ### Question 8

# %% [markdown]
# ### Question 9 - For each property we store review scores across different metrics (accuracy, check-in, cleanliness etc). We consider adding more metrics, although there is no clarity on what these will be. We want to be able to easily query the average score across all of these metrics, including any new metrics that might be added without changing the query. Adjust the data model so this can be done and show the query for an example property.

# %%
pipeline = [
    {"$match": {"review_scores": {"$exists": True, "$ne": {}}}}, #check if review_scores exists and is not null
    {"$project": {"_id": 1, "scores": {"$objectToArray": "$review_scores"}}},
    {"$project": {"_id": 1, "average_score": {"$avg": "$scores.v"}}},
    {"$group": {"_id": "$_id", "average_score": {"$avg": "$average_score"}}}
]



result = list(db.listingsAndReviews.aggregate(pipeline))

for i in result:
    pprint(i)
# Out:
# {'_id': '22574501', 'average_score': 20.0}
# {'_id': '16653189', 'average_score': 22.714285714285715}
# {'_id': '17613188', 'average_score': 22.857142857142858}
# {'_id': '23509750', 'average_score': 22.571428571428573}
# {'_id': '31582808', 'average_score': 22.714285714285715}
# {'_id': '11567815', 'average_score': 22.571428571428573}
# {'_id': '30092212', 'average_score': 22.857142857142858}
# {'_id': '25961494', 'average_score': 22.714285714285715}
# {'_id': '555588', 'average_score': 22.142857142857142}
# {'_id': '6316666', 'average_score': 16.285714285714285}
# {'_id': '20580703', 'average_score': 18.571428571428573}
# {'_id': '13764019', 'average_score': 22.571428571428573}
# {'_id': '3953585', 'average_score': 22.285714285714285}
# {'_id': '3288363', 'average_score': 22.857142857142858}
# {'_id': '1586454', 'average_score': 18.285714285714285}
# {'_id': '24186748', 'average_score': 22.428571428571427}
# {'_id': '14462759', 'average_score': 22.857142857142858}
# {'_id': '17223695', 'average_score': 22.714285714285715}
# {'_id': '7549277', 'average_score': 22.857142857142858}
# {'_id': '2253500', 'average_score': 20.571428571428573}
# {'_id': '15245956', 'average_score': 19.142857142857142}
# {'_id': '15285714', 'average_score': 22.0}
# {'_id': '7912090', 'average_score': 18.714285714285715}
# {'_id': '18215903', 'average_score': 20.0}
# {'_id': '14992196', 'average_score': 21.857142857142858}
# {'_id': '20677942', 'average_score': 18.571428571428573}
# {'_id': '21526718', 'average_score': 18.428571428571427}
# {'_id': '5640127', 'average_score': 22.857142857142858}
# {'_id': '18103340', 'average_score': 22.142857142857142}
# {'_id': '1148978', 'average_score': 21.428571428571427}
# {'_id': '8293756', 'average_score': 22.857142857142858}
# {'_id': '18083735', 'average_score': 22.714285714285715}
# {'_id': '23222456', 'average_score': 22.0}
# {'_id': '24993202', 'average_score': 22.857142857142858}
# {'_id': '17827642', 'average_score': 21.857142857142858}
# {'_id': '24461891', 'average_score': 22.571428571428573}
# {'_id': '865148', 'average_score': 20.714285714285715}
# {'_id': '13750579', 'average_score': 22.142857142857142}
# {'_id': '1731242', 'average_score': 21.285714285714285}
# {'_id': '14375153', 'average_score': 21.571428571428573}
# {'_id': '91439', 'average_score': 22.142857142857142}
# {'_id': '12586942', 'average_score': 21.714285714285715}
# {'_id': '1574416', 'average_score': 22.571428571428573}
# {'_id': '14146422', 'average_score': 22.857142857142858}
# {'_id': '21977972', 'average_score': 19.857142857142858}
# {'_id': '13771436', 'average_score': 21.714285714285715}
# {'_id': '14629833', 'average_score': 22.285714285714285}
# {'_id': '24899410', 'average_score': 22.571428571428573}
# {'_id': '1266425', 'average_score': 19.285714285714285}
# {'_id': '15748933', 'average_score': 22.428571428571427}
# {'_id': '16336615', 'average_score': 22.857142857142858}
# {'_id': '18077770', 'average_score': 21.857142857142858}
# {'_id': '17861859', 'average_score': 22.714285714285715}
# {'_id': '21127680', 'average_score': 21.428571428571427}
# {'_id': '14827972', 'average_score': 22.285714285714285}
# {'_id': '1206820', 'average_score': 22.142857142857142}
# {'_id': '20695115', 'average_score': 22.571428571428573}
# {'_id': '23493822', 'average_score': 21.428571428571427}
# {'_id': '2538085', 'average_score': 22.857142857142858}
# {'_id': '27630706', 'average_score': 17.571428571428573}
# {'_id': '14249346', 'average_score': 21.0}
# {'_id': '12409013', 'average_score': 22.0}
# {'_id': '490098', 'average_score': 22.428571428571427}
# {'_id': '29456207', 'average_score': 18.857142857142858}
# {'_id': '16408272', 'average_score': 21.142857142857142}
# {'_id': '2851471', 'average_score': 22.142857142857142}
# {'_id': '12906000', 'average_score': 20.285714285714285}
# {'_id': '19244141', 'average_score': 20.571428571428573}
# {'_id': '28750603', 'average_score': 21.571428571428573}
# {'_id': '13743786', 'average_score': 20.714285714285715}
# {'_id': '20357635', 'average_score': 22.714285714285715}
# {'_id': '24863216', 'average_score': 22.714285714285715}
# {'_id': '6457918', 'average_score': 22.428571428571427}
# {'_id': '7997236', 'average_score': 20.857142857142858}
# {'_id': '23479384', 'average_score': 21.714285714285715}
# {'_id': '20677646', 'average_score': 22.857142857142858}
# {'_id': '3530395', 'average_score': 22.857142857142858}
# {'_id': '8356824', 'average_score': 21.142857142857142}
# {'_id': '7715270', 'average_score': 21.857142857142858}
# {'_id': '24845400', 'average_score': 22.714285714285715}
# {'_id': '4052514', 'average_score': 22.428571428571427}
# {'_id': '16978814', 'average_score': 22.857142857142858}
# {'_id': '19587471', 'average_score': 21.571428571428573}
# {'_id': '15436372', 'average_score': 22.714285714285715}
# {'_id': '13063723', 'average_score': 20.428571428571427}
# {'_id': '2769600', 'average_score': 22.571428571428573}
# {'_id': '24945999', 'average_score': 20.428571428571427}
# {'_id': '6349210', 'average_score': 22.571428571428573}
# {'_id': '16381905', 'average_score': 20.571428571428573}
# {'_id': '20172538', 'average_score': 19.428571428571427}
# {'_id': '13520692', 'average_score': 20.0}
# {'_id': '253842', 'average_score': 22.285714285714285}
# {'_id': '29338509', 'average_score': 22.857142857142858}
# {'_id': '21987106', 'average_score': 22.857142857142858}
# {'_id': '9597872', 'average_score': 22.0}
# {'_id': '888107', 'average_score': 21.0}
# {'_id': '12222943', 'average_score': 20.857142857142858}
# {'_id': '23046994', 'average_score': 22.857142857142858}
# {'_id': '13161668', 'average_score': 21.857142857142858}
# {'_id': '510923', 'average_score': 21.285714285714285}
# {'_id': '10742116', 'average_score': 19.571428571428573}
# {'_id': '24917020', 'average_score': 22.857142857142858}
# {'_id': '14573570', 'average_score': 22.714285714285715}
# {'_id': '17305490', 'average_score': 22.0}
# {'_id': '878307', 'average_score': 21.571428571428573}
# {'_id': '12607396', 'average_score': 22.285714285714285}
# {'_id': '19080306', 'average_score': 22.285714285714285}
# {'_id': '24981028', 'average_score': 19.857142857142858}
# {'_id': '11553357', 'average_score': 21.714285714285715}
# {'_id': '2274454', 'average_score': 21.714285714285715}
# {'_id': '14923016', 'average_score': 22.571428571428573}
# {'_id': '15208698', 'average_score': 22.571428571428573}
# {'_id': '19508741', 'average_score': 22.857142857142858}
# {'_id': '9990304', 'average_score': 22.285714285714285}
# {'_id': '8246966', 'average_score': 22.714285714285715}
# {'_id': '4372254', 'average_score': 19.714285714285715}
# {'_id': '12857433', 'average_score': 22.0}
# {'_id': '6771249', 'average_score': 20.714285714285715}
# {'_id': '928725', 'average_score': 21.428571428571427}
# {'_id': '20720421', 'average_score': 19.571428571428573}
# {'_id': '19499950', 'average_score': 21.142857142857142}
# {'_id': '13304991', 'average_score': 22.428571428571427}
# {'_id': '2054110', 'average_score': 22.571428571428573}
# {'_id': '20724571', 'average_score': 20.857142857142858}
# {'_id': '4505004', 'average_score': 22.142857142857142}
# {'_id': '10228731', 'average_score': 22.571428571428573}
# {'_id': '13495314', 'average_score': 22.571428571428573}
# {'_id': '23978926', 'average_score': 22.285714285714285}
# {'_id': '9848837', 'average_score': 19.714285714285715}
# {'_id': '11921637', 'average_score': 21.428571428571427}
# {'_id': '11145180', 'average_score': 21.285714285714285}
# {'_id': '16708536', 'average_score': 21.285714285714285}
# {'_id': '26231187', 'average_score': 22.714285714285715}
# {'_id': '19995621', 'average_score': 12.428571428571429}
# {'_id': '20570876', 'average_score': 22.285714285714285}
# {'_id': '7815865', 'average_score': 22.428571428571427}
# {'_id': '25653807', 'average_score': 22.714285714285715}
# {'_id': '24211932', 'average_score': 22.571428571428573}
# {'_id': '3410502', 'average_score': 22.285714285714285}
# {'_id': '12954762', 'average_score': 22.142857142857142}
# {'_id': '30115488', 'average_score': 21.714285714285715}
# {'_id': '3238474', 'average_score': 17.571428571428573}
# {'_id': '30368243', 'average_score': 22.857142857142858}
# {'_id': '1584102', 'average_score': 22.571428571428573}
# {'_id': '290608', 'average_score': 22.857142857142858}
# {'_id': '1359438', 'average_score': 22.0}
# {'_id': '22295401', 'average_score': 22.428571428571427}
# {'_id': '2629234', 'average_score': 22.857142857142858}
# {'_id': '23007600', 'average_score': 21.714285714285715}
# {'_id': '24818739', 'average_score': 20.714285714285715}
# {'_id': '5407374', 'average_score': 22.142857142857142}
# {'_id': '19005784', 'average_score': 21.142857142857142}
# {'_id': '12046370', 'average_score': 22.285714285714285}
# {'_id': '21946009', 'average_score': 22.142857142857142}
# {'_id': '24857815', 'average_score': 22.857142857142858}
# {'_id': '28475232', 'average_score': 22.285714285714285}
# {'_id': '21669322', 'average_score': 22.285714285714285}
# {'_id': '1487222', 'average_score': 19.857142857142858}
# {'_id': '31099467', 'average_score': 9.714285714285714}
# {'_id': '577242', 'average_score': 21.285714285714285}
# {'_id': '4454553', 'average_score': 22.285714285714285}
# {'_id': '31123905', 'average_score': 22.857142857142858}
# {'_id': '10057826', 'average_score': 20.428571428571427}
# {'_id': '11005300', 'average_score': 22.857142857142858}
# {'_id': '20088277', 'average_score': 20.428571428571427}
# {'_id': '8958638', 'average_score': 22.0}
# {'_id': '29952115', 'average_score': 22.857142857142858}
# {'_id': '21234040', 'average_score': 33.0}
# {'_id': '29957113', 'average_score': 21.428571428571427}
# {'_id': '9951865', 'average_score': 22.857142857142858}
# {'_id': '1805685', 'average_score': 20.428571428571427}
# {'_id': '27784079', 'average_score': 22.142857142857142}
# {'_id': '31630832', 'average_score': 14.0}
# {'_id': '8664238', 'average_score': 19.714285714285715}
# {'_id': '18586018', 'average_score': 22.285714285714285}
# {'_id': '31101349', 'average_score': 20.571428571428573}
# {'_id': '17173473', 'average_score': 20.285714285714285}
# {'_id': '22265304', 'average_score': 18.857142857142858}
# {'_id': '21531457', 'average_score': 22.285714285714285}
# {'_id': '9313155', 'average_score': 22.571428571428573}
# {'_id': '14758081', 'average_score': 22.0}
# {'_id': '21281467', 'average_score': 22.857142857142858}
# {'_id': '17083946', 'average_score': 21.857142857142858}
# {'_id': '25136779', 'average_score': 20.857142857142858}
# {'_id': '26764641', 'average_score': 21.0}
# {'_id': '27590942', 'average_score': 20.571428571428573}
# {'_id': '10802909', 'average_score': 18.571428571428573}
# {'_id': '12223067', 'average_score': 22.571428571428573}
# {'_id': '1459519', 'average_score': 22.0}
# {'_id': '28889655', 'average_score': 21.285714285714285}
# {'_id': '32024517', 'average_score': 22.0}
# {'_id': '27473087', 'average_score': 22.857142857142858}
# {'_id': '10527212', 'average_score': 16.714285714285715}
# {'_id': '23989053', 'average_score': 21.285714285714285}
# {'_id': '21895438', 'average_score': 22.857142857142858}
# {'_id': '1132409', 'average_score': 21.857142857142858}
# {'_id': '29390089', 'average_score': 22.857142857142858}
# {'_id': '18312333', 'average_score': 17.714285714285715}
# {'_id': '4826466', 'average_score': 20.0}
# {'_id': '2187610', 'average_score': 21.285714285714285}
# {'_id': '23122981', 'average_score': 20.428571428571427}
# {'_id': '24511562', 'average_score': 20.428571428571427}
# {'_id': '21998466', 'average_score': 20.0}
# {'_id': '30926186', 'average_score': 22.857142857142858}
# {'_id': '15285878', 'average_score': 22.857142857142858}
# {'_id': '23471052', 'average_score': 20.571428571428573}
# {'_id': '7840953', 'average_score': 22.571428571428573}
# {'_id': '16193945', 'average_score': 20.857142857142858}
# {'_id': '11871088', 'average_score': 20.571428571428573}
# {'_id': '28545400', 'average_score': 21.857142857142858}
# {'_id': '20035273', 'average_score': 18.285714285714285}
# {'_id': '24187105', 'average_score': 22.857142857142858}
# {'_id': '27012681', 'average_score': 22.857142857142858}
# {'_id': '808705', 'average_score': 22.428571428571427}
# {'_id': '21762139', 'average_score': 22.285714285714285}
# {'_id': '16717755', 'average_score': 22.857142857142858}
# {'_id': '25014628', 'average_score': 22.714285714285715}
# {'_id': '30294051', 'average_score': 19.142857142857142}
# {'_id': '3494585', 'average_score': 21.0}
# {'_id': '12873224', 'average_score': 19.714285714285715}
# {'_id': '13764334', 'average_score': 19.714285714285715}
# {'_id': '2711936', 'average_score': 22.714285714285715}
# {'_id': '9746950', 'average_score': 19.142857142857142}
# {'_id': '13711161', 'average_score': 22.0}
# {'_id': '1332929', 'average_score': 21.857142857142858}
# {'_id': '12157453', 'average_score': 22.0}
# {'_id': '28543237', 'average_score': 22.857142857142858}
# {'_id': '1058555', 'average_score': 22.142857142857142}
# {'_id': '20557566', 'average_score': 22.714285714285715}
# {'_id': '19664691', 'average_score': 21.714285714285715}
# {'_id': '26209883', 'average_score': 22.428571428571427}
# {'_id': '9296889', 'average_score': 22.142857142857142}
# {'_id': '18905958', 'average_score': 14.428571428571429}
# {'_id': '21939239', 'average_score': 22.714285714285715}
# {'_id': '25997982', 'average_score': 22.857142857142858}
# {'_id': '18694750', 'average_score': 22.857142857142858}
# {'_id': '31644399', 'average_score': 22.571428571428573}
# {'_id': '29121570', 'average_score': 21.857142857142858}
# {'_id': '22811503', 'average_score': 22.285714285714285}
# {'_id': '14501655', 'average_score': 22.142857142857142}
# {'_id': '26925918', 'average_score': 20.0}
# {'_id': '22182637', 'average_score': 21.857142857142858}
# {'_id': '1413677', 'average_score': 22.0}
# {'_id': '17584746', 'average_score': 22.142857142857142}
# {'_id': '27003273', 'average_score': 18.285714285714285}
# {'_id': '12886223', 'average_score': 22.857142857142858}
# {'_id': '10648267', 'average_score': 22.857142857142858}
# {'_id': '17140064', 'average_score': 21.142857142857142}
# {'_id': '22717303', 'average_score': 22.285714285714285}
# {'_id': '29474090', 'average_score': 22.714285714285715}
# {'_id': '7286036', 'average_score': 21.285714285714285}
# {'_id': '7311170', 'average_score': 22.571428571428573}
# {'_id': '11796483', 'average_score': 21.142857142857142}
# {'_id': '21536635', 'average_score': 22.714285714285715}
# {'_id': '23650892', 'average_score': 20.714285714285715}
# {'_id': '9703075', 'average_score': 22.285714285714285}
# {'_id': '4790136', 'average_score': 22.571428571428573}
# {'_id': '4758009', 'average_score': 22.857142857142858}
# {'_id': '30239722', 'average_score': 22.857142857142858}
# {'_id': '21637487', 'average_score': 22.571428571428573}
# {'_id': '17624702', 'average_score': 22.571428571428573}
# {'_id': '23357535', 'average_score': 21.285714285714285}
# {'_id': '15190865', 'average_score': 22.428571428571427}
# {'_id': '18935312', 'average_score': 22.571428571428573}
# {'_id': '16020247', 'average_score': 21.714285714285715}
# {'_id': '19846740', 'average_score': 19.714285714285715}
# {'_id': '6534803', 'average_score': 22.857142857142858}
# {'_id': '11860692', 'average_score': 22.714285714285715}
# {'_id': '223200', 'average_score': 21.714285714285715}
# {'_id': '25503822', 'average_score': 20.285714285714285}
# {'_id': '29283991', 'average_score': 21.0}
# {'_id': '8571561', 'average_score': 22.571428571428573}
# {'_id': '1704560', 'average_score': 22.428571428571427}
# {'_id': '13585970', 'average_score': 22.857142857142858}
# {'_id': '26430039', 'average_score': 22.714285714285715}
# {'_id': '11093339', 'average_score': 22.0}
# {'_id': '15719888', 'average_score': 19.714285714285715}
# {'_id': '571382', 'average_score': 22.285714285714285}
# {'_id': '15139440', 'average_score': 17.428571428571427}
# {'_id': '13603801', 'average_score': 21.857142857142858}
# {'_id': '30365974', 'average_score': 21.285714285714285}
# {'_id': '20728606', 'average_score': 22.714285714285715}
# {'_id': '20941829', 'average_score': 22.0}
# {'_id': '17028088', 'average_score': 22.714285714285715}
# {'_id': '21563508', 'average_score': 21.428571428571427}
# {'_id': '11602050', 'average_score': 18.428571428571427}
# {'_id': '14173253', 'average_score': 15.0}
# {'_id': '210968', 'average_score': 21.571428571428573}
# {'_id': '22613522', 'average_score': 22.714285714285715}
# {'_id': '18121163', 'average_score': 21.0}
# {'_id': '29109214', 'average_score': 20.0}
# {'_id': '30261334', 'average_score': 22.857142857142858}
# {'_id': '4589874', 'average_score': 21.714285714285715}
# {'_id': '13366855', 'average_score': 20.714285714285715}
# {'_id': '20827801', 'average_score': 22.428571428571427}
# {'_id': '22161352', 'average_score': 21.142857142857142}
# {'_id': '23953865', 'average_score': 20.0}
# {'_id': '28904599', 'average_score': 14.857142857142858}
# {'_id': '31666595', 'average_score': 22.0}
# {'_id': '26287233', 'average_score': 21.0}
# {'_id': '2881549', 'average_score': 22.857142857142858}
# {'_id': '12604062', 'average_score': 22.571428571428573}
# {'_id': '170150', 'average_score': 22.571428571428573}
# {'_id': '1036027', 'average_score': 20.571428571428573}
# {'_id': '12791827', 'average_score': 21.142857142857142}
# {'_id': '1593570', 'average_score': 22.0}
# {'_id': '1410460', 'average_score': 21.857142857142858}
# {'_id': '1907162', 'average_score': 19.714285714285715}
# {'_id': '5850712', 'average_score': 22.571428571428573}
# {'_id': '21686582', 'average_score': 22.857142857142858}
# {'_id': '29799437', 'average_score': 22.857142857142858}
# {'_id': '15004284', 'average_score': 22.571428571428573}
# {'_id': '31013832', 'average_score': 21.857142857142858}
# {'_id': '26842020', 'average_score': 22.285714285714285}
# {'_id': '31867873', 'average_score': 22.857142857142858}
# {'_id': '7364008', 'average_score': 20.714285714285715}
# {'_id': '19692712', 'average_score': 21.714285714285715}
# {'_id': '17639835', 'average_score': 22.714285714285715}
# {'_id': '14610596', 'average_score': 21.571428571428573}
# {'_id': '19309013', 'average_score': 22.857142857142858}
# {'_id': '27617820', 'average_score': 18.285714285714285}
# {'_id': '15771501', 'average_score': 21.285714285714285}
# {'_id': '5549057', 'average_score': 22.714285714285715}
# {'_id': '9280084', 'average_score': 21.142857142857142}
# {'_id': '1198074', 'average_score': 22.571428571428573}
# {'_id': '19807212', 'average_score': 22.857142857142858}
# {'_id': '14650584', 'average_score': 22.285714285714285}
# {'_id': '28232832', 'average_score': 21.714285714285715}
# {'_id': '23519016', 'average_score': 19.428571428571427}
# {'_id': '6836536', 'average_score': 21.428571428571427}
# {'_id': '16981802', 'average_score': 21.0}
# {'_id': '20530001', 'average_score': 19.714285714285715}
# {'_id': '12800556', 'average_score': 19.857142857142858}
# {'_id': '27083634', 'average_score': 21.571428571428573}
# {'_id': '5194434', 'average_score': 21.142857142857142}
# {'_id': '13762136', 'average_score': 22.714285714285715}
# {'_id': '484267', 'average_score': 22.571428571428573}
# {'_id': '24859326', 'average_score': 21.571428571428573}
# {'_id': '18387366', 'average_score': 21.714285714285715}
# {'_id': '17136808', 'average_score': 20.571428571428573}
# {'_id': '4621926', 'average_score': 22.0}
# {'_id': '7246903', 'average_score': 21.285714285714285}
# {'_id': '24903500', 'average_score': 20.0}
# {'_id': '25881010', 'average_score': 22.857142857142858}
# {'_id': '28407128', 'average_score': 22.428571428571427}
# {'_id': '1145567', 'average_score': 20.142857142857142}
# {'_id': '10092679', 'average_score': 22.428571428571427}
# {'_id': '19935458', 'average_score': 20.571428571428573}
# {'_id': '8521963', 'average_score': 21.857142857142858}
# {'_id': '25484862', 'average_score': 21.428571428571427}
# {'_id': '11846549', 'average_score': 21.142857142857142}
# {'_id': '28258693', 'average_score': 4.571428571428571}
# {'_id': '30301460', 'average_score': 19.142857142857142}
# {'_id': '27989463', 'average_score': 22.857142857142858}
# {'_id': '10096773', 'average_score': 22.857142857142858}
# {'_id': '8980230', 'average_score': 22.857142857142858}
# {'_id': '22382752', 'average_score': 20.428571428571427}
# {'_id': '1001265', 'average_score': 19.714285714285715}
# {'_id': '2113358', 'average_score': 20.0}
# {'_id': '4870358', 'average_score': 21.142857142857142}
# {'_id': '8581508', 'average_score': 22.142857142857142}
# {'_id': '10558807', 'average_score': 16.857142857142858}
# {'_id': '23284399', 'average_score': 21.571428571428573}
# {'_id': '26829659', 'average_score': 21.714285714285715}
# {'_id': '32510052', 'average_score': 22.857142857142858}
# {'_id': '28795425', 'average_score': 22.0}
# {'_id': '25437034', 'average_score': 22.857142857142858}
# {'_id': '14967994', 'average_score': 22.142857142857142}
# {'_id': '19981060', 'average_score': 22.714285714285715}
# {'_id': '28493488', 'average_score': 22.857142857142858}
# {'_id': '2909689', 'average_score': 22.857142857142858}
# {'_id': '30729906', 'average_score': 22.857142857142858}
# {'_id': '12189083', 'average_score': 21.714285714285715}
# {'_id': '15550900', 'average_score': 21.428571428571427}
# {'_id': '19049757', 'average_score': 21.857142857142858}
# {'_id': '23822150', 'average_score': 22.285714285714285}
# {'_id': '27045941', 'average_score': 20.0}
# {'_id': '32436791', 'average_score': 22.857142857142858}
# {'_id': '24693627', 'average_score': 18.857142857142858}
# {'_id': '2681468', 'average_score': 21.428571428571427}
# {'_id': '18734995', 'average_score': 22.285714285714285}
# {'_id': '342139', 'average_score': 19.714285714285715}
# {'_id': '3527622', 'average_score': 21.142857142857142}
# {'_id': '10545815', 'average_score': 22.0}
# {'_id': '32160778', 'average_score': 21.714285714285715}
# {'_id': '18421662', 'average_score': 21.857142857142858}
# {'_id': '4270866', 'average_score': 21.0}
# {'_id': '11242147', 'average_score': 22.857142857142858}
# {'_id': '6201263', 'average_score': 20.0}
# {'_id': '484390', 'average_score': 21.428571428571427}
# {'_id': '30857458', 'average_score': 22.857142857142858}
# {'_id': '4413137', 'average_score': 21.0}
# {'_id': '25794804', 'average_score': 22.285714285714285}
# {'_id': '6183610', 'average_score': 22.428571428571427}
# {'_id': '18272882', 'average_score': 22.142857142857142}
# {'_id': '15820774', 'average_score': 21.428571428571427}
# {'_id': '12401124', 'average_score': 21.571428571428573}
# {'_id': '22336599', 'average_score': 22.142857142857142}
# {'_id': '22624198', 'average_score': 19.857142857142858}
# {'_id': '23435015', 'average_score': 22.428571428571427}
# {'_id': '9834391', 'average_score': 22.428571428571427}
# {'_id': '22179180', 'average_score': 22.142857142857142}
# {'_id': '18134491', 'average_score': 21.0}
# {'_id': '8118692', 'average_score': 19.714285714285715}
# {'_id': '6813540', 'average_score': 17.714285714285715}
# {'_id': '4211510', 'average_score': 19.0}
# {'_id': '7970000', 'average_score': 18.428571428571427}
# {'_id': '8341415', 'average_score': 22.714285714285715}
# {'_id': '17829178', 'average_score': 20.714285714285715}
# {'_id': '16262122', 'average_score': 22.428571428571427}
# {'_id': '18047246', 'average_score': 22.285714285714285}
# {'_id': '27383511', 'average_score': 13.428571428571429}
# {'_id': '19694143', 'average_score': 22.714285714285715}
# {'_id': '27011219', 'average_score': 22.428571428571427}
# {'_id': '13814845', 'average_score': 22.142857142857142}
# {'_id': '1796816', 'average_score': 22.285714285714285}
# {'_id': '27272282', 'average_score': 22.714285714285715}
# {'_id': '11719579', 'average_score': 22.857142857142858}
# {'_id': '16744615', 'average_score': 22.714285714285715}
# {'_id': '23572358', 'average_score': 14.0}
# {'_id': '14574409', 'average_score': 22.142857142857142}
# {'_id': '24279661', 'average_score': 21.857142857142858}
# {'_id': '17960308', 'average_score': 22.857142857142858}
# {'_id': '1169088', 'average_score': 19.857142857142858}
# {'_id': '19993317', 'average_score': 22.857142857142858}
# {'_id': '16261574', 'average_score': 20.571428571428573}
# {'_id': '19961067', 'average_score': 22.571428571428573}
# {'_id': '19767452', 'average_score': 22.285714285714285}
# {'_id': '26474245', 'average_score': 22.428571428571427}
# {'_id': '20211255', 'average_score': 22.571428571428573}
# {'_id': '29821133', 'average_score': 22.857142857142858}
# {'_id': '24298167', 'average_score': 22.428571428571427}
# {'_id': '3261569', 'average_score': 21.428571428571427}
# {'_id': '26436758', 'average_score': 21.571428571428573}
# {'_id': '20755043', 'average_score': 22.857142857142858}
# {'_id': '6795568', 'average_score': 21.428571428571427}
# {'_id': '7843851', 'average_score': 22.714285714285715}
# {'_id': '25070084', 'average_score': 22.571428571428573}
# {'_id': '16057052', 'average_score': 22.857142857142858}
# {'_id': '2296225', 'average_score': 22.285714285714285}
# {'_id': '13390320', 'average_score': 22.142857142857142}
# {'_id': '7276469', 'average_score': 19.571428571428573}
# {'_id': '16777456', 'average_score': 22.0}
# {'_id': '18446434', 'average_score': 20.857142857142858}
# {'_id': '1635900', 'average_score': 22.285714285714285}
# {'_id': '4025482', 'average_score': 22.285714285714285}
# {'_id': '5283892', 'average_score': 21.285714285714285}
# {'_id': '6583887', 'average_score': 20.428571428571427}
# {'_id': '6977204', 'average_score': 21.571428571428573}
# {'_id': '14493885', 'average_score': 22.857142857142858}
# {'_id': '28690892', 'average_score': 22.142857142857142}
# {'_id': '29447285', 'average_score': 22.857142857142858}
# {'_id': '23688192', 'average_score': 22.285714285714285}
# {'_id': '10299095', 'average_score': 18.285714285714285}
# {'_id': '19838729', 'average_score': 20.714285714285715}
# {'_id': '8553863', 'average_score': 20.857142857142858}
# {'_id': '1910291', 'average_score': 22.0}
# {'_id': '31080472', 'average_score': 22.857142857142858}
# {'_id': '4924343', 'average_score': 22.285714285714285}
# {'_id': '23374190', 'average_score': 22.571428571428573}
# {'_id': '11764681', 'average_score': 21.0}
# {'_id': '9567840', 'average_score': 20.571428571428573}
# {'_id': '19746798', 'average_score': 22.571428571428573}
# {'_id': '20450522', 'average_score': 22.428571428571427}
# {'_id': '4318532', 'average_score': 17.142857142857142}
# {'_id': '31217955', 'average_score': 22.285714285714285}
# {'_id': '20698056', 'average_score': 18.285714285714285}
# {'_id': '22020910', 'average_score': 22.714285714285715}
# {'_id': '30421791', 'average_score': 22.857142857142858}
# {'_id': '27983285', 'average_score': 22.857142857142858}
# {'_id': '8144456', 'average_score': 19.857142857142858}
# {'_id': '16703046', 'average_score': 21.0}
# {'_id': '27794194', 'average_score': 22.714285714285715}
# {'_id': '7322621', 'average_score': 19.571428571428573}
# {'_id': '323213', 'average_score': 21.857142857142858}
# {'_id': '29274583', 'average_score': 22.571428571428573}
# {'_id': '901441', 'average_score': 22.857142857142858}
# {'_id': '17252454', 'average_score': 22.714285714285715}
# {'_id': '19310295', 'average_score': 22.285714285714285}
# {'_id': '20522971', 'average_score': 22.857142857142858}
# {'_id': '2314585', 'average_score': 22.0}
# {'_id': '2738727', 'average_score': 20.428571428571427}
# {'_id': '5447255', 'average_score': 21.285714285714285}
# {'_id': '1920293', 'average_score': 22.714285714285715}
# {'_id': '314982', 'average_score': 22.142857142857142}
# {'_id': '25501014', 'average_score': 21.857142857142858}
# {'_id': '14460432', 'average_score': 22.714285714285715}
# {'_id': '24032849', 'average_score': 22.0}
# {'_id': '24717812', 'average_score': 22.857142857142858}
# {'_id': '24146463', 'average_score': 22.0}
# {'_id': '457829', 'average_score': 19.428571428571427}
# {'_id': '21648821', 'average_score': 20.857142857142858}
# {'_id': '2607583', 'average_score': 21.428571428571427}
# {'_id': '259661', 'average_score': 22.285714285714285}
# {'_id': '30323119', 'average_score': 22.714285714285715}
# {'_id': '5249793', 'average_score': 21.0}
# {'_id': '16636716', 'average_score': 25.0}
# {'_id': '5923031', 'average_score': 22.571428571428573}
# {'_id': '7394730', 'average_score': 22.428571428571427}
# {'_id': '16397486', 'average_score': 20.857142857142858}
# {'_id': '22131624', 'average_score': 21.0}
# {'_id': '12098138', 'average_score': 22.714285714285715}
# {'_id': '16837578', 'average_score': 22.857142857142858}
# {'_id': '29947519', 'average_score': 22.142857142857142}
# {'_id': '2493382', 'average_score': 21.714285714285715}
# {'_id': '15003496', 'average_score': 21.571428571428573}
# {'_id': '27581537', 'average_score': 22.428571428571427}
# {'_id': '29009853', 'average_score': 22.428571428571427}
# {'_id': '2856208', 'average_score': 21.428571428571427}
# {'_id': '16719714', 'average_score': 20.714285714285715}
# {'_id': '27366599', 'average_score': 22.0}
# {'_id': '20543265', 'average_score': 22.714285714285715}
# {'_id': '1042446', 'average_score': 21.714285714285715}
# {'_id': '218191', 'average_score': 21.428571428571427}
# {'_id': '17951038', 'average_score': 22.285714285714285}
# {'_id': '27968507', 'average_score': 22.142857142857142}
# {'_id': '4573398', 'average_score': 20.571428571428573}
# {'_id': '20055551', 'average_score': 20.857142857142858}
# {'_id': '30951435', 'average_score': 22.714285714285715}
# {'_id': '3210248', 'average_score': 22.428571428571427}
# {'_id': '32839070', 'average_score': 22.857142857142858}
# {'_id': '22155071', 'average_score': 22.428571428571427}
# {'_id': '30973353', 'average_score': 22.857142857142858}
# {'_id': '26816279', 'average_score': 21.571428571428573}
# {'_id': '22860459', 'average_score': 21.857142857142858}
# {'_id': '22600065', 'average_score': 15.714285714285714}
# {'_id': '17742384', 'average_score': 21.285714285714285}
# {'_id': '27590773', 'average_score': 22.857142857142858}
# {'_id': '28373585', 'average_score': 21.857142857142858}
# {'_id': '16468473', 'average_score': 20.857142857142858}
# {'_id': '9853331', 'average_score': 21.714285714285715}
# {'_id': '1604488', 'average_score': 22.714285714285715}
# {'_id': '9200371', 'average_score': 22.714285714285715}
# {'_id': '193105', 'average_score': 22.142857142857142}
# {'_id': '24955954', 'average_score': 22.857142857142858}
# {'_id': '10117617', 'average_score': 22.142857142857142}
# {'_id': '22101558', 'average_score': 19.142857142857142}
# {'_id': '1406337', 'average_score': 19.714285714285715}
# {'_id': '1534038', 'average_score': 22.857142857142858}
# {'_id': '1799637', 'average_score': 18.571428571428573}
# {'_id': '31058753', 'average_score': 22.857142857142858}
# {'_id': '6844367', 'average_score': 13.714285714285714}
# {'_id': '11055163', 'average_score': 20.571428571428573}
# {'_id': '18294732', 'average_score': 20.857142857142858}
# {'_id': '21204926', 'average_score': 20.285714285714285}
# {'_id': '9557097', 'average_score': 18.714285714285715}
# {'_id': '3580577', 'average_score': 22.142857142857142}
# {'_id': '564564', 'average_score': 20.571428571428573}
# {'_id': '15762813', 'average_score': 21.428571428571427}
# {'_id': '6974185', 'average_score': 22.714285714285715}
# {'_id': '7983543', 'average_score': 21.428571428571427}
# {'_id': '15828858', 'average_score': 22.285714285714285}
# {'_id': '19660411', 'average_score': 21.285714285714285}
# {'_id': '2724572', 'average_score': 21.857142857142858}
# {'_id': '5260247', 'average_score': 22.571428571428573}
# {'_id': '23494020', 'average_score': 22.571428571428573}
# {'_id': '11902059', 'average_score': 21.857142857142858}
# {'_id': '16289600', 'average_score': 16.0}
# {'_id': '22295354', 'average_score': 22.714285714285715}
# {'_id': '22075258', 'average_score': 22.285714285714285}
# {'_id': '22730070', 'average_score': 17.285714285714285}
# {'_id': '15744249', 'average_score': 21.571428571428573}
# {'_id': '18345625', 'average_score': 22.714285714285715}
# {'_id': '31059672', 'average_score': 22.857142857142858}
# {'_id': '17132840', 'average_score': 22.285714285714285}
# {'_id': '24868157', 'average_score': 21.714285714285715}
# {'_id': '2163225', 'average_score': 20.714285714285715}
# {'_id': '11144250', 'average_score': 21.714285714285715}
# {'_id': '25446051', 'average_score': 21.428571428571427}
# {'_id': '27568440', 'average_score': 22.285714285714285}
# {'_id': '9524926', 'average_score': 22.285714285714285}
# {'_id': '22085738', 'average_score': 22.571428571428573}
# {'_id': '26257930', 'average_score': 22.857142857142858}
# {'_id': '25996203', 'average_score': 22.857142857142858}
# {'_id': '12027124', 'average_score': 22.571428571428573}
# {'_id': '24755982', 'average_score': 22.857142857142858}
# {'_id': '24207163', 'average_score': 22.428571428571427}
# {'_id': '10948197', 'average_score': 21.285714285714285}
# {'_id': '438923', 'average_score': 21.857142857142858}
# {'_id': '6774703', 'average_score': 19.285714285714285}
# {'_id': '29456015', 'average_score': 22.571428571428573}
# {'_id': '20845825', 'average_score': 20.142857142857142}
# {'_id': '12810796', 'average_score': 19.714285714285715}
# {'_id': '22165464', 'average_score': 18.571428571428573}
# {'_id': '25726820', 'average_score': 22.285714285714285}
# {'_id': '23926355', 'average_score': 22.857142857142858}
# {'_id': '29821233', 'average_score': 22.285714285714285}
# {'_id': '4952989', 'average_score': 22.571428571428573}
# {'_id': '5927726', 'average_score': 21.714285714285715}
# {'_id': '2422745', 'average_score': 22.571428571428573}
# {'_id': '22192465', 'average_score': 20.857142857142858}
# {'_id': '6357355', 'average_score': 22.857142857142858}
# {'_id': '13490410', 'average_score': 21.571428571428573}
# {'_id': '21244482', 'average_score': 22.142857142857142}
# {'_id': '24916356', 'average_score': 22.285714285714285}
# {'_id': '7265155', 'average_score': 22.857142857142858}
# {'_id': '9907103', 'average_score': 22.714285714285715}
# {'_id': '28218289', 'average_score': 22.857142857142858}
# {'_id': '31095245', 'average_score': 22.857142857142858}
# {'_id': '2279098', 'average_score': 21.285714285714285}
# {'_id': '6542159', 'average_score': 22.857142857142858}
# {'_id': '22066860', 'average_score': 22.285714285714285}
# {'_id': '22362742', 'average_score': 22.285714285714285}
# {'_id': '6908603', 'average_score': 22.857142857142858}
# {'_id': '15417267', 'average_score': 18.571428571428573}
# {'_id': '73683', 'average_score': 21.285714285714285}
# {'_id': '31506064', 'average_score': 14.857142857142858}
# {'_id': '18255921', 'average_score': 22.857142857142858}
# {'_id': '19220115', 'average_score': 22.285714285714285}
# {'_id': '26739925', 'average_score': 20.142857142857142}
# {'_id': '30982784', 'average_score': 22.857142857142858}
# {'_id': '21005012', 'average_score': 22.857142857142858}
# {'_id': '22323221', 'average_score': 22.0}
# {'_id': '19786915', 'average_score': 20.714285714285715}
# {'_id': '25715808', 'average_score': 22.571428571428573}
# {'_id': '31135824', 'average_score': 20.428571428571427}
# {'_id': '14044480', 'average_score': 19.857142857142858}
# {'_id': '1746726', 'average_score': 22.142857142857142}
# {'_id': '18954080', 'average_score': 22.571428571428573}
# {'_id': '28835255', 'average_score': 22.0}
# {'_id': '2118641', 'average_score': 20.857142857142858}
# {'_id': '30495625', 'average_score': 22.857142857142858}
# {'_id': '12874776', 'average_score': 22.857142857142858}
# {'_id': '7069636', 'average_score': 20.428571428571427}
# {'_id': '2029840', 'average_score': 17.285714285714285}
# {'_id': '22108306', 'average_score': 22.857142857142858}
# {'_id': '8432091', 'average_score': 21.142857142857142}
# {'_id': '17996862', 'average_score': 22.142857142857142}
# {'_id': '13789278', 'average_score': 20.571428571428573}
# {'_id': '28402495', 'average_score': 22.571428571428573}
# {'_id': '9767864', 'average_score': 21.857142857142858}
# {'_id': '10141950', 'average_score': 22.857142857142858}
# {'_id': '19104230', 'average_score': 22.857142857142858}
# {'_id': '17913605', 'average_score': 22.857142857142858}
# {'_id': '17663877', 'average_score': 19.428571428571427}
# {'_id': '4318601', 'average_score': 20.571428571428573}
# {'_id': '19920988', 'average_score': 19.0}
# {'_id': '289703', 'average_score': 22.857142857142858}
# {'_id': '9422452', 'average_score': 21.285714285714285}
# {'_id': '15177216', 'average_score': 22.714285714285715}
# {'_id': '17124591', 'average_score': 22.428571428571427}
# {'_id': '15893952', 'average_score': 22.0}
# {'_id': '12514918', 'average_score': 22.142857142857142}
# {'_id': '13308110', 'average_score': 20.714285714285715}
# {'_id': '19014550', 'average_score': 22.0}
# {'_id': '30116382', 'average_score': 22.285714285714285}
# {'_id': '32369195', 'average_score': 5.142857142857143}
# {'_id': '23650296', 'average_score': 21.142857142857142}
# {'_id': '27555785', 'average_score': 22.857142857142858}
# {'_id': '6291063', 'average_score': 22.857142857142858}
# {'_id': '19246639', 'average_score': 21.714285714285715}
# {'_id': '2820832', 'average_score': 22.285714285714285}
# {'_id': '17453748', 'average_score': 21.285714285714285}
# {'_id': '24938559', 'average_score': 4.571428571428571}
# {'_id': '4902451', 'average_score': 22.714285714285715}
# {'_id': '6046461', 'average_score': 22.714285714285715}
# {'_id': '20724431', 'average_score': 22.285714285714285}
# {'_id': '24492886', 'average_score': 16.142857142857142}
# {'_id': '21155900', 'average_score': 13.142857142857142}
# {'_id': '19501264', 'average_score': 22.857142857142858}
# {'_id': '4304899', 'average_score': 22.428571428571427}
# {'_id': '929583', 'average_score': 22.285714285714285}
# {'_id': '939657', 'average_score': 21.714285714285715}
# {'_id': '32287835', 'average_score': 12.857142857142858}
# {'_id': '191079', 'average_score': 21.857142857142858}
# {'_id': '20865085', 'average_score': 22.714285714285715}
# {'_id': '539140', 'average_score': 22.857142857142858}
# {'_id': '16182647', 'average_score': 21.428571428571427}
# {'_id': '14649808', 'average_score': 21.857142857142858}
# {'_id': '20906942', 'average_score': 21.142857142857142}
# {'_id': '6601944', 'average_score': 21.857142857142858}
# {'_id': '20845108', 'average_score': 22.571428571428573}
# {'_id': '13726629', 'average_score': 20.142857142857142}
# {'_id': '18415512', 'average_score': 21.0}
# {'_id': '30322438', 'average_score': 21.714285714285715}
# {'_id': '19928786', 'average_score': 22.571428571428573}
# {'_id': '6262821', 'average_score': 21.714285714285715}
# {'_id': '20116519', 'average_score': 22.0}
# {'_id': '28926167', 'average_score': 22.857142857142858}
# {'_id': '11753116', 'average_score': 20.714285714285715}
# {'_id': '1583670', 'average_score': 20.0}
# {'_id': '1427233', 'average_score': 19.857142857142858}
# {'_id': '16147485', 'average_score': 22.285714285714285}
# {'_id': '27791633', 'average_score': 22.857142857142858}
# {'_id': '14930875', 'average_score': 19.857142857142858}
# {'_id': '10021707', 'average_score': 22.285714285714285}
# {'_id': '6610629', 'average_score': 22.428571428571427}
# {'_id': '13146333', 'average_score': 21.428571428571427}
# {'_id': '9696653', 'average_score': 21.285714285714285}
# {'_id': '21237763', 'average_score': 22.857142857142858}
# {'_id': '28629163', 'average_score': 22.857142857142858}
# {'_id': '12971533', 'average_score': 22.571428571428573}
# {'_id': '17446640', 'average_score': 22.142857142857142}
# {'_id': '6316121', 'average_score': 22.428571428571427}
# {'_id': '9195855', 'average_score': 18.571428571428573}
# {'_id': '6944286', 'average_score': 21.428571428571427}
# {'_id': '1688924', 'average_score': 21.142857142857142}
# {'_id': '16952227', 'average_score': 20.285714285714285}
# {'_id': '19526091', 'average_score': 21.714285714285715}
# {'_id': '5505414', 'average_score': 19.142857142857142}
# {'_id': '28858840', 'average_score': 17.857142857142858}
# {'_id': '11740322', 'average_score': 22.714285714285715}
# {'_id': '8027341', 'average_score': 22.285714285714285}
# {'_id': '7773322', 'average_score': 22.714285714285715}
# {'_id': '28838517', 'average_score': 22.142857142857142}
# {'_id': '1482060', 'average_score': 21.285714285714285}
# {'_id': '14309960', 'average_score': 22.714285714285715}
# {'_id': '23321866', 'average_score': 21.285714285714285}
# {'_id': '13799611', 'average_score': 21.142857142857142}
# {'_id': '23759457', 'average_score': 22.857142857142858}
# {'_id': '19555586', 'average_score': 22.428571428571427}
# {'_id': '13923606', 'average_score': 19.142857142857142}
# {'_id': '24212994', 'average_score': 22.0}
# {'_id': '24019419', 'average_score': 22.0}
# {'_id': '16288457', 'average_score': 22.428571428571427}
# {'_id': '23679945', 'average_score': 21.714285714285715}
# {'_id': '16765282', 'average_score': 22.857142857142858}
# {'_id': '22266125', 'average_score': 21.571428571428573}
# {'_id': '3952093', 'average_score': 21.142857142857142}
# {'_id': '7660936', 'average_score': 22.142857142857142}
# {'_id': '12290090', 'average_score': 22.571428571428573}
# {'_id': '10051164', 'average_score': 18.285714285714285}
# {'_id': '15806964', 'average_score': 22.714285714285715}
# {'_id': '19559597', 'average_score': 22.428571428571427}
# {'_id': '598612', 'average_score': 21.857142857142858}
# {'_id': '794910', 'average_score': 21.571428571428573}
# {'_id': '9802077', 'average_score': 22.285714285714285}
# {'_id': '14741201', 'average_score': 20.857142857142858}
# {'_id': '6945434', 'average_score': 16.285714285714285}
# {'_id': '16178963', 'average_score': 22.857142857142858}
# {'_id': '15902696', 'average_score': 22.714285714285715}
# {'_id': '3014692', 'average_score': 21.857142857142858}
# {'_id': '15036568', 'average_score': 20.142857142857142}
# {'_id': '20511510', 'average_score': 19.285714285714285}
# {'_id': '9156574', 'average_score': 20.714285714285715}
# {'_id': '14339793', 'average_score': 22.857142857142858}
# {'_id': '19779206', 'average_score': 19.142857142857142}
# {'_id': '19847790', 'average_score': 20.428571428571427}
# {'_id': '26415333', 'average_score': 20.571428571428573}
# {'_id': '15095488', 'average_score': 21.285714285714285}
# {'_id': '11264406', 'average_score': 22.857142857142858}
# {'_id': '602888', 'average_score': 21.142857142857142}
# {'_id': '15650737', 'average_score': 21.571428571428573}
# {'_id': '18918530', 'average_score': 22.142857142857142}
# {'_id': '14094561', 'average_score': 13.142857142857142}
# {'_id': '22367184', 'average_score': 22.285714285714285}
# {'_id': '30364518', 'average_score': 19.714285714285715}
# {'_id': '941361', 'average_score': 22.714285714285715}
# {'_id': '4974771', 'average_score': 22.857142857142858}
# {'_id': '15194147', 'average_score': 18.428571428571427}
# {'_id': '744242', 'average_score': 20.714285714285715}
# {'_id': '17124786', 'average_score': 21.571428571428573}
# {'_id': '14214403', 'average_score': 22.571428571428573}
# {'_id': '17048768', 'average_score': 21.857142857142858}
# {'_id': '2351455', 'average_score': 22.857142857142858}
# {'_id': '24391397', 'average_score': 22.857142857142858}
# {'_id': '9172046', 'average_score': 22.285714285714285}
# {'_id': '31670584', 'average_score': 22.857142857142858}
# {'_id': '2153435', 'average_score': 22.0}
# {'_id': '4348703', 'average_score': 22.571428571428573}
# {'_id': '10612199', 'average_score': 22.857142857142858}
# {'_id': '1836793', 'average_score': 22.428571428571427}
# {'_id': '21624000', 'average_score': 21.571428571428573}
# {'_id': '29078967', 'average_score': 22.571428571428573}
# {'_id': '20588113', 'average_score': 22.714285714285715}
# {'_id': '27013325', 'average_score': 22.142857142857142}
# {'_id': '29997747', 'average_score': 21.857142857142858}
# {'_id': '20701559', 'average_score': 22.857142857142858}
# {'_id': '16389574', 'average_score': 21.857142857142858}
# {'_id': '17001994', 'average_score': 22.142857142857142}
# {'_id': '25803387', 'average_score': 22.0}
# {'_id': '23312848', 'average_score': 21.714285714285715}
# {'_id': '27366716', 'average_score': 18.571428571428573}
# {'_id': '18091109', 'average_score': 19.857142857142858}
# {'_id': '29503086', 'average_score': 22.857142857142858}
# {'_id': '13511610', 'average_score': 22.714285714285715}
# {'_id': '10908640', 'average_score': 22.428571428571427}
# {'_id': '220946', 'average_score': 20.857142857142858}
# {'_id': '31548152', 'average_score': 20.714285714285715}
# {'_id': '4449066', 'average_score': 21.857142857142858}
# {'_id': '13318405', 'average_score': 22.428571428571427}
# {'_id': '16812225', 'average_score': 18.571428571428573}
# {'_id': '30826856', 'average_score': 22.142857142857142}
# {'_id': '17832869', 'average_score': 22.714285714285715}
# {'_id': '25819967', 'average_score': 22.571428571428573}
# {'_id': '12448766', 'average_score': 22.571428571428573}
# {'_id': '19750905', 'average_score': 21.428571428571427}
# {'_id': '7270389', 'average_score': 21.142857142857142}
# {'_id': '11835169', 'average_score': 22.714285714285715}
# {'_id': '30538139', 'average_score': 20.428571428571427}
# {'_id': '310233', 'average_score': 22.285714285714285}
# {'_id': '16341825', 'average_score': 22.857142857142858}
# {'_id': '9701620', 'average_score': 22.0}
# {'_id': '19550563', 'average_score': 21.857142857142858}
# {'_id': '5926953', 'average_score': 21.428571428571427}
# {'_id': '19018752', 'average_score': 22.857142857142858}
# {'_id': '25082056', 'average_score': 22.857142857142858}
# {'_id': '31804891', 'average_score': 18.285714285714285}
# {'_id': '24785954', 'average_score': 18.285714285714285}
# {'_id': '31827679', 'average_score': 19.142857142857142}
# {'_id': '19963866', 'average_score': 20.0}
# {'_id': '12906100', 'average_score': 21.428571428571427}
# {'_id': '26558762', 'average_score': 22.857142857142858}
# {'_id': '22509800', 'average_score': 21.714285714285715}
# {'_id': '24735200', 'average_score': 22.857142857142858}
# {'_id': '19028601', 'average_score': 22.857142857142858}
# {'_id': '16686102', 'average_score': 22.857142857142858}
# {'_id': '5618084', 'average_score': 20.428571428571427}
# {'_id': '26185187', 'average_score': 22.857142857142858}
# {'_id': '30824244', 'average_score': 22.857142857142858}
# {'_id': '17734475', 'average_score': 22.571428571428573}
# {'_id': '21947380', 'average_score': 21.428571428571427}
# {'_id': '3735449', 'average_score': 21.571428571428573}
# {'_id': '2578814', 'average_score': 21.714285714285715}
# {'_id': '26405954', 'average_score': 20.714285714285715}
# {'_id': '17466973', 'average_score': 21.714285714285715}
# {'_id': '17296538', 'average_score': 20.142857142857142}
# {'_id': '20763432', 'average_score': 22.571428571428573}
# {'_id': '27372346', 'average_score': 22.571428571428573}
# {'_id': '524729', 'average_score': 20.142857142857142}
# {'_id': '14996051', 'average_score': 22.571428571428573}
# {'_id': '21382912', 'average_score': 17.142857142857142}
# {'_id': '22269344', 'average_score': 22.857142857142858}
# {'_id': '19029043', 'average_score': 22.714285714285715}
# {'_id': '18859786', 'average_score': 22.428571428571427}
# {'_id': '22585112', 'average_score': 22.0}
# {'_id': '2314392', 'average_score': 22.0}
# {'_id': '20135359', 'average_score': 22.285714285714285}
# {'_id': '17494671', 'average_score': 22.714285714285715}
# {'_id': '25264318', 'average_score': 21.142857142857142}
# {'_id': '8365099', 'average_score': 22.857142857142858}
# {'_id': '2576604', 'average_score': 21.714285714285715}
# {'_id': '18611535', 'average_score': 21.714285714285715}
# {'_id': '20692275', 'average_score': 21.857142857142858}
# {'_id': '2159898', 'average_score': 22.714285714285715}
# {'_id': '125656', 'average_score': 22.857142857142858}
# {'_id': '27044783', 'average_score': 17.714285714285715}
# {'_id': '10227000', 'average_score': 22.571428571428573}
# {'_id': '19426217', 'average_score': 20.714285714285715}
# {'_id': '19699590', 'average_score': 21.142857142857142}
# {'_id': '26532170', 'average_score': 15.142857142857142}
# {'_id': '10415637', 'average_score': 22.571428571428573}
# {'_id': '1176693', 'average_score': 19.714285714285715}
# {'_id': '14490025', 'average_score': 20.857142857142858}
# {'_id': '16067483', 'average_score': 21.285714285714285}
# {'_id': '27335708', 'average_score': 22.857142857142858}
# {'_id': '27588189', 'average_score': 19.285714285714285}
# {'_id': '6694877', 'average_score': 22.714285714285715}
# {'_id': '32008854', 'average_score': 22.857142857142858}
# {'_id': '7247033', 'average_score': 22.0}
# {'_id': '4021526', 'average_score': 22.142857142857142}
# {'_id': '535213', 'average_score': 22.0}
# {'_id': '2228863', 'average_score': 21.857142857142858}
# {'_id': '117425', 'average_score': 20.714285714285715}
# {'_id': '1255979', 'average_score': 22.0}
# {'_id': '17464256', 'average_score': 22.428571428571427}
# {'_id': '16550219', 'average_score': 21.428571428571427}
# {'_id': '22058660', 'average_score': 22.714285714285715}
# {'_id': '32385079', 'average_score': 22.857142857142858}
# {'_id': '24970484', 'average_score': 22.857142857142858}
# {'_id': '3654407', 'average_score': 22.857142857142858}
# {'_id': '21493665', 'average_score': 22.142857142857142}
# {'_id': '5554583', 'average_score': 22.285714285714285}
# {'_id': '15529123', 'average_score': 22.571428571428573}
# {'_id': '8662829', 'average_score': 21.857142857142858}
# {'_id': '19086528', 'average_score': 22.857142857142858}
# {'_id': '4957358', 'average_score': 22.142857142857142}
# ...
# {'_id': '10887852', 'average_score': 22.142857142857142}
# {'_id': '2563967', 'average_score': 22.0}
# {'_id': '16195143', 'average_score': 20.714285714285715}
# {'_id': '21739859', 'average_score': 21.714285714285715}
# {'_id': '2432138', 'average_score': 20.714285714285715}
# {'_id': '16532230', 'average_score': 22.285714285714285}
# {'_id': '19044796', 'average_score': 22.428571428571427}
# {'_id': '1095174', 'average_score': 22.285714285714285}
# {'_id': '1079887', 'average_score': 21.428571428571427}
# {'_id': '1676806', 'average_score': 22.571428571428573}
# {'_id': '17757695', 'average_score': 19.0}
# {'_id': '22856113', 'average_score': 22.0}
# {'_id': '30194213', 'average_score': 21.428571428571427}
# {'_id': '17625824', 'average_score': 19.142857142857142}
# {'_id': '23428550', 'average_score': 20.0}
# {'_id': '22891830', 'average_score': 21.0}
# {'_id': '3021624', 'average_score': 22.142857142857142}
# {'_id': '19741944', 'average_score': 18.714285714285715}
# {'_id': '19585860', 'average_score': 22.857142857142858}
# {'_id': '1101035', 'average_score': 22.428571428571427}
# {'_id': '13934996', 'average_score': 22.857142857142858}
# {'_id': '28609655', 'average_score': 22.428571428571427}
# {'_id': '28829890', 'average_score': 22.714285714285715}
# {'_id': '18769857', 'average_score': 21.571428571428573}
# {'_id': '2927005', 'average_score': 22.428571428571427}
# {'_id': '15551245', 'average_score': 22.857142857142858}
# {'_id': '1182475', 'average_score': 20.285714285714285}
# {'_id': '16239737', 'average_score': 22.571428571428573}
# {'_id': '16559061', 'average_score': 22.857142857142858}
# {'_id': '5449320', 'average_score': 15.857142857142858}
# {'_id': '27436445', 'average_score': 22.285714285714285}
# {'_id': '840731', 'average_score': 22.142857142857142}
# {'_id': '32546486', 'average_score': 22.857142857142858}
# {'_id': '23465144', 'average_score': 21.857142857142858}
# {'_id': '30511700', 'average_score': 22.857142857142858}
# {'_id': '7958920', 'average_score': 19.142857142857142}
# {'_id': '8386906', 'average_score': 22.428571428571427}
# {'_id': '1144090', 'average_score': 21.571428571428573}
# {'_id': '18571579', 'average_score': 22.571428571428573}
# {'_id': '644378', 'average_score': 22.428571428571427}
# {'_id': '13605461', 'average_score': 22.0}
# {'_id': '14295981', 'average_score': 22.857142857142858}
# {'_id': '24290706', 'average_score': 22.428571428571427}
# {'_id': '4940063', 'average_score': 20.428571428571427}
# {'_id': '19990097', 'average_score': 21.714285714285715}
# {'_id': '24461559', 'average_score': 22.857142857142858}
# {'_id': '20860562', 'average_score': 22.428571428571427}
# {'_id': '24340252', 'average_score': 21.714285714285715}
# {'_id': '15003187', 'average_score': 22.857142857142858}
# {'_id': '22153101', 'average_score': 22.285714285714285}
# {'_id': '4776811', 'average_score': 22.857142857142858}
# {'_id': '19952004', 'average_score': 20.571428571428573}
# {'_id': '12814401', 'average_score': 22.571428571428573}
# {'_id': '21832585', 'average_score': 21.142857142857142}
# {'_id': '23720900', 'average_score': 22.571428571428573}
# {'_id': '2758817', 'average_score': 22.142857142857142}
# {'_id': '7398141', 'average_score': 21.142857142857142}
# {'_id': '7674190', 'average_score': 22.142857142857142}
# {'_id': '8559496', 'average_score': 22.428571428571427}
# {'_id': '13193079', 'average_score': 14.857142857142858}
# {'_id': '7382567', 'average_score': 21.0}
# {'_id': '6262536', 'average_score': 22.857142857142858}
# {'_id': '2105881', 'average_score': 20.571428571428573}
# {'_id': '12713962', 'average_score': 21.571428571428573}
# {'_id': '4178152', 'average_score': 20.428571428571427}
# {'_id': '7801169', 'average_score': 22.714285714285715}
# {'_id': '20307844', 'average_score': 20.857142857142858}
# {'_id': '22622636', 'average_score': 22.428571428571427}
# {'_id': '19929723', 'average_score': 21.571428571428573}
# {'_id': '30087365', 'average_score': 22.428571428571427}
# {'_id': '20726731', 'average_score': 4.571428571428571}
# {'_id': '6264804', 'average_score': 22.857142857142858}
# {'_id': '3618467', 'average_score': 20.142857142857142}
# {'_id': '8747128', 'average_score': 22.0}
# {'_id': '26103478', 'average_score': 21.285714285714285}
# {'_id': '6314480', 'average_score': 21.714285714285715}
# {'_id': '15812792', 'average_score': 19.857142857142858}
# {'_id': '28438885', 'average_score': 22.857142857142858}
# {'_id': '26493902', 'average_score': 17.285714285714285}
# {'_id': '26320917', 'average_score': 17.714285714285715}
# {'_id': '15015363', 'average_score': 22.428571428571427}
# {'_id': '25485516', 'average_score': 22.714285714285715}
# {'_id': '297908', 'average_score': 21.714285714285715}
# {'_id': '15098676', 'average_score': 20.142857142857142}
# {'_id': '10392282', 'average_score': 22.0}
# {'_id': '4451485', 'average_score': 22.571428571428573}
# {'_id': '3102202', 'average_score': 21.428571428571427}
# {'_id': '21451259', 'average_score': 22.714285714285715}
# {'_id': '20804897', 'average_score': 15.428571428571429}
# {'_id': '27452326', 'average_score': 6.0}
# {'_id': '7099038', 'average_score': 22.285714285714285}
# {'_id': '13302796', 'average_score': 21.0}
# {'_id': '1476484', 'average_score': 19.571428571428573}
# {'_id': '9599384', 'average_score': 22.428571428571427}
# {'_id': '15126808', 'average_score': 20.714285714285715}
# {'_id': '16078823', 'average_score': 21.857142857142858}
# {'_id': '25684995', 'average_score': 21.142857142857142}
# {'_id': '12211157', 'average_score': 22.571428571428573}
# {'_id': '20822448', 'average_score': 21.142857142857142}
# {'_id': '18358621', 'average_score': 22.285714285714285}
# {'_id': '20767798', 'average_score': 20.142857142857142}
# {'_id': '14175496', 'average_score': 22.857142857142858}
# {'_id': '15031608', 'average_score': 22.571428571428573}
# {'_id': '12639342', 'average_score': 22.571428571428573}
# {'_id': '143175', 'average_score': 21.571428571428573}
# {'_id': '24159286', 'average_score': 20.714285714285715}
# {'_id': '3322110', 'average_score': 21.571428571428573}
# {'_id': '20965875', 'average_score': 21.0}
# {'_id': '18120094', 'average_score': 20.142857142857142}
# {'_id': '13110019', 'average_score': 22.857142857142858}
# {'_id': '23160633', 'average_score': 22.857142857142858}
# {'_id': '1925045', 'average_score': 22.571428571428573}
# {'_id': '15657910', 'average_score': 15.428571428571429}
# {'_id': '12591225', 'average_score': 19.714285714285715}
# {'_id': '17319360', 'average_score': 19.857142857142858}
# {'_id': '11779701', 'average_score': 20.714285714285715}
# {'_id': '27873052', 'average_score': 22.857142857142858}
# {'_id': '3532235', 'average_score': 22.857142857142858}
# {'_id': '19038282', 'average_score': 22.428571428571427}
# {'_id': '15100883', 'average_score': 15.142857142857142}
# {'_id': '19100444', 'average_score': 21.857142857142858}
# {'_id': '14161011', 'average_score': 18.142857142857142}
# {'_id': '26609688', 'average_score': 22.857142857142858}
# {'_id': '19680142', 'average_score': 20.0}
# {'_id': '29673222', 'average_score': 22.0}
# {'_id': '30222713', 'average_score': 17.714285714285715}
# {'_id': '31086693', 'average_score': 21.428571428571427}
# {'_id': '15904149', 'average_score': 19.714285714285715}
# {'_id': '3517150', 'average_score': 22.428571428571427}
# {'_id': '29761068', 'average_score': 22.857142857142858}
# {'_id': '1131054', 'average_score': 22.714285714285715}
# {'_id': '19416383', 'average_score': 22.571428571428573}
# {'_id': '29500826', 'average_score': 22.857142857142858}
# {'_id': '25829784', 'average_score': 20.428571428571427}
# {'_id': '5725151', 'average_score': 22.142857142857142}
# {'_id': '27834501', 'average_score': 22.857142857142858}
# {'_id': '13155211', 'average_score': 21.142857142857142}
# {'_id': '7546623', 'average_score': 21.142857142857142}
# {'_id': '29974058', 'average_score': 19.142857142857142}
# {'_id': '25541515', 'average_score': 22.0}
# {'_id': '4450120', 'average_score': 21.714285714285715}
# {'_id': '13361526', 'average_score': 22.142857142857142}
# {'_id': '6611547', 'average_score': 21.857142857142858}
# {'_id': '1530241', 'average_score': 21.428571428571427}
# {'_id': '10635276', 'average_score': 22.857142857142858}
# {'_id': '8650800', 'average_score': 19.0}
# {'_id': '16560886', 'average_score': 22.571428571428573}
# {'_id': '2071929', 'average_score': 22.285714285714285}
# {'_id': '21497042', 'average_score': 22.857142857142858}
# {'_id': '12091977', 'average_score': 20.857142857142858}
# {'_id': '30203828', 'average_score': 21.142857142857142}
# {'_id': '20945783', 'average_score': 19.428571428571427}
# {'_id': '20521331', 'average_score': 22.285714285714285}
# {'_id': '28307606', 'average_score': 22.857142857142858}
# {'_id': '4294289', 'average_score': 22.428571428571427}
# {'_id': '11191242', 'average_score': 20.714285714285715}
# {'_id': '14856799', 'average_score': 21.428571428571427}
# {'_id': '640813', 'average_score': 21.857142857142858}
# {'_id': '4797773', 'average_score': 22.142857142857142}
# {'_id': '15797728', 'average_score': 22.428571428571427}
# {'_id': '19348489', 'average_score': 22.857142857142858}
# {'_id': '8106459', 'average_score': 22.285714285714285}
# {'_id': '27789416', 'average_score': 21.428571428571427}
# {'_id': '4532565', 'average_score': 22.428571428571427}
# {'_id': '7037584', 'average_score': 21.714285714285715}
# {'_id': '1223747', 'average_score': 21.714285714285715}
# {'_id': '16107698', 'average_score': 21.142857142857142}
# {'_id': '16517991', 'average_score': 22.285714285714285}
# {'_id': '440924', 'average_score': 22.285714285714285}
# {'_id': '16635022', 'average_score': 22.285714285714285}
# {'_id': '13844617', 'average_score': 17.714285714285715}
# {'_id': '20677802', 'average_score': 22.142857142857142}
# {'_id': '21986801', 'average_score': 22.857142857142858}
# {'_id': '2875373', 'average_score': 22.714285714285715}
# {'_id': '19134150', 'average_score': 22.857142857142858}
# {'_id': '20711019', 'average_score': 20.142857142857142}
# {'_id': '11840338', 'average_score': 22.857142857142858}
# {'_id': '14506036', 'average_score': 21.571428571428573}
# {'_id': '4178954', 'average_score': 21.285714285714285}
# {'_id': '927923', 'average_score': 22.714285714285715}
# {'_id': '17531493', 'average_score': 21.285714285714285}
# {'_id': '4586762', 'average_score': 21.428571428571427}
# {'_id': '8778128', 'average_score': 21.428571428571427}
# {'_id': '21893035', 'average_score': 17.428571428571427}
# {'_id': '3602073', 'average_score': 22.857142857142858}
# {'_id': '29837246', 'average_score': 21.285714285714285}
# {'_id': '20669488', 'average_score': 21.428571428571427}
# {'_id': '27650961', 'average_score': 22.857142857142858}
# {'_id': '32332063', 'average_score': 22.0}
# {'_id': '4798216', 'average_score': 21.285714285714285}
# {'_id': '5068892', 'average_score': 20.857142857142858}
# {'_id': '22164073', 'average_score': 22.0}
# {'_id': '6140179', 'average_score': 20.428571428571427}
# {'_id': '1284892', 'average_score': 20.857142857142858}
# {'_id': '12137640', 'average_score': 20.571428571428573}
# {'_id': '30104792', 'average_score': 7.428571428571429}
# {'_id': '2265321', 'average_score': 21.428571428571427}
# {'_id': '4778098', 'average_score': 19.285714285714285}
# {'_id': '19664709', 'average_score': 18.142857142857142}
# {'_id': '19177584', 'average_score': 21.0}
# {'_id': '21716100', 'average_score': 21.0}
# {'_id': '9448927', 'average_score': 22.857142857142858}
# {'_id': '19572281', 'average_score': 22.714285714285715}
# {'_id': '29448000', 'average_score': 22.714285714285715}
# {'_id': '7697720', 'average_score': 21.714285714285715}
# {'_id': '22042558', 'average_score': 22.142857142857142}
# {'_id': '23211669', 'average_score': 21.428571428571427}
# {'_id': '10840938', 'average_score': 20.428571428571427}
# {'_id': '26728997', 'average_score': 22.571428571428573}
# {'_id': '23066385', 'average_score': 21.571428571428573}
# {'_id': '29115387', 'average_score': 22.857142857142858}
# {'_id': '31951516', 'average_score': 22.857142857142858}
# {'_id': '961596', 'average_score': 20.857142857142858}
# {'_id': '26487387', 'average_score': 22.571428571428573}
# {'_id': '6381542', 'average_score': 21.285714285714285}
# {'_id': '6627075', 'average_score': 20.0}
# {'_id': '27934911', 'average_score': 21.571428571428573}
# {'_id': '26414600', 'average_score': 8.0}
# {'_id': '23180898', 'average_score': 20.857142857142858}
# {'_id': '22942398', 'average_score': 22.714285714285715}
# {'_id': '1858521', 'average_score': 22.571428571428573}
# {'_id': '13227163', 'average_score': 20.142857142857142}
# {'_id': '21988560', 'average_score': 22.714285714285715}
# {'_id': '5080547', 'average_score': 19.428571428571427}
# {'_id': '8672496', 'average_score': 22.428571428571427}
# {'_id': '17344027', 'average_score': 22.285714285714285}
# {'_id': '14223095', 'average_score': 22.142857142857142}
# {'_id': '24858356', 'average_score': 22.0}
# {'_id': '20483790', 'average_score': 22.285714285714285}
# {'_id': '2682827', 'average_score': 20.571428571428573}
# {'_id': '26712529', 'average_score': 21.142857142857142}
# {'_id': '14993652', 'average_score': 21.857142857142858}
# {'_id': '17045341', 'average_score': 22.142857142857142}
# {'_id': '2967668', 'average_score': 22.285714285714285}
# {'_id': '5121635', 'average_score': 21.142857142857142}
# {'_id': '20038668', 'average_score': 20.857142857142858}
# {'_id': '4204302', 'average_score': 16.714285714285715}
# {'_id': '3503965', 'average_score': 17.571428571428573}
# {'_id': '5250762', 'average_score': 21.428571428571427}
# {'_id': '8092787', 'average_score': 7.0}
# {'_id': '30956518', 'average_score': 20.428571428571427}
# {'_id': '13999182', 'average_score': 22.571428571428573}
# {'_id': '5083829', 'average_score': 21.714285714285715}
# {'_id': '17944310', 'average_score': 21.714285714285715}
# {'_id': '1619695', 'average_score': 21.285714285714285}
# {'_id': '20374683', 'average_score': 21.428571428571427}
# {'_id': '28002020', 'average_score': 6.285714285714286}
# {'_id': '25266022', 'average_score': 22.714285714285715}
# {'_id': '967346', 'average_score': 20.428571428571427}
# {'_id': '2515976', 'average_score': 21.0}
# {'_id': '4773338', 'average_score': 20.428571428571427}
# {'_id': '9379065', 'average_score': 22.142857142857142}
# {'_id': '26319639', 'average_score': 22.857142857142858}
# {'_id': '31696863', 'average_score': 22.714285714285715}
# {'_id': '13382536', 'average_score': 22.857142857142858}
# {'_id': '20530526', 'average_score': 22.428571428571427}
# {'_id': '30325676', 'average_score': 22.857142857142858}
# {'_id': '10264100', 'average_score': 22.714285714285715}
# {'_id': '2741869', 'average_score': 21.142857142857142}
# {'_id': '21711468', 'average_score': 22.571428571428573}
# {'_id': '17797004', 'average_score': 22.142857142857142}
# {'_id': '10659534', 'average_score': 21.714285714285715}
# {'_id': '4962247', 'average_score': 22.857142857142858}
# {'_id': '13883147', 'average_score': 22.571428571428573}
# {'_id': '27573376', 'average_score': 22.714285714285715}
# {'_id': '32178403', 'average_score': 21.0}
# {'_id': '1321072', 'average_score': 22.285714285714285}
# {'_id': '28603723', 'average_score': 22.571428571428573}
# {'_id': '27720921', 'average_score': 22.714285714285715}
# {'_id': '5814254', 'average_score': 22.428571428571427}
# {'_id': '12357386', 'average_score': 22.285714285714285}
# {'_id': '15060713', 'average_score': 22.0}
# {'_id': '21819120', 'average_score': 21.142857142857142}
# {'_id': '2949309', 'average_score': 21.0}
# {'_id': '14894267', 'average_score': 22.714285714285715}
# {'_id': '18569613', 'average_score': 20.571428571428573}
# {'_id': '30234270', 'average_score': 22.857142857142858}
# {'_id': '12256344', 'average_score': 22.714285714285715}
# {'_id': '22385219', 'average_score': 22.285714285714285}
# {'_id': '5093778', 'average_score': 22.857142857142858}
# {'_id': '23872995', 'average_score': 19.571428571428573}
# {'_id': '27932125', 'average_score': 22.857142857142858}
# {'_id': '28805946', 'average_score': 22.428571428571427}
# {'_id': '31176187', 'average_score': 19.142857142857142}
# {'_id': '6422511', 'average_score': 21.714285714285715}
# {'_id': '2991893', 'average_score': 22.142857142857142}
# {'_id': '9505003', 'average_score': 22.857142857142858}
# {'_id': '25148829', 'average_score': 22.428571428571427}
# {'_id': '31164170', 'average_score': 22.857142857142858}

# %%
#Example:
pipeline = [
    {"$match": {"_id": "22200454", "review_scores": {"$exists": True, "$ne": []}}},
    {"$unwind": "$review_scores"},
    {"$group": {"_id": "$_id", "average_score": {"$avg": "$review_scores.score"}}}
]

result = list(db.listingsAndReviews.aggregate(pipeline))

print(result)
# Out:
# [{'_id': '22200454', 'average_score': None}]

# %%
#para ver a db. Depois apagar.
document = db.listingsAndReviews.find({"_id": "9505003"})

for doc in document:
    pprint(doc)
# Out:
# {'_id': '9505003',
#  'access': 'Your room, the bureau, bathroom, kitchen, veranda and backyard.',
#  'accommodates': 2,
#  'address': {'country': 'Canada',
#              'country_code': 'CA',
#              'government_area': 'Rosemont-La Petite-Patrie',
#              'location': {'coordinates': [-73.60577, 45.54015],
#                           'is_location_exact': True,
#                           'type': 'Point'},
#              'market': 'Montreal',
#              'street': 'Montréal, Québec, Canada',
#              'suburb': 'La Petite-Patrie'},
#  'amenities': ['Internet',
#                'Wifi',
#                'Kitchen',
#                'Pets live on this property',
#                'Dog(s)',
#                'Free street parking',
#                'Heating',
#                'Family/kid friendly',
#                'Suitable for events',
#                'Washer',
#                'Smoke detector',
#                'First aid kit',
#                'Fire extinguisher',
#                'Essentials',
#                'Shampoo',
#                'Lock on bedroom door',
#                'Hangers',
#                'Hair dryer',
#                'Laptop friendly workspace',
#                'Hot water',
#                'Coffee maker',
#                'Refrigerator',
#                'Dishwasher',
#                'Dishes and silverware',
#                'Cooking basics',
#                'Oven',
#                'Stove',
#                'Patio or balcony',
#                'Garden or backyard',
#                'Luggage dropoff allowed',
#                'Other'],
#  'availability': {'availability_30': 29,
#                   'availability_365': 179,
#                   'availability_60': 59,
#                   'availability_90': 89},
#  'bathrooms': Decimal128('1.0'),
#  'bed_type': 'Real Bed',
#  'bedrooms': 1,
#  'beds': 1,
#  'calendar_last_scraped': datetime.datetime(2019, 3, 11, 4, 0),
#  'cancellation_policy': 'moderate',
#  'cleaning_fee': Decimal128('20.00'),
#  'description': 'Beautiful and luminous room in Rosemont Petite Patrie! The '
#                 'apartment has three bedrooms (mine, yours and another for '
#                 'travelers), plus a bureau, a kitchen, a semi-finished '
#                 'basement, a veranda and a large backyard to which you have '
#                 'access! You can find anything you want in the neighboorhood '
#                 'from parc, cafes, bars, grocery stores, etc. You have access '
#                 'to two metro within 10 minute walk and the cycle path is '
#                 'right is passing right in front of the appartment. We look '
#                 'forward to welcoming you! Currently, the house is occupied by '
#                 'Xavier, Jessica and Juliet (my dog). Jessica is completing '
#                 'her MA in Political History; she advocates for progressive '
#                 'causes and is also interested in the arts and the circus. You '
#                 'can look at my profile to learn more about me. Juliette is a '
#                 'truly dog angel (very calm and affectionate)! Thank you for '
#                 'writing a detailed and personalized request to give us an '
#                 'idea of what kind of person and roommate you are. Your room, '
#                 'the bureau, bathroom, kitchen, veranda and backyard',
#  'extra_people': Decimal128('20.00'),
#  'first_review': datetime.datetime(2016, 6, 27, 4, 0),
#  'guests_included': Decimal128('1'),
#  'host': {'host_about': "Je pratique plusieurs formes d'art : théâtre, "
#                         "photographie, écriture, musique. J'aime me promener "
#                         'dans la ville sans but précis tout en lisant, prenant '
#                         "des photos, dansant, etc. Je suis quelqu'un de plutôt "
#                         "introverti sans toutefois être timide. J'apprécie les "
#                         'lieux alternatifs, que ce soit des commerces ou des '
#                         'lieux extérieurs. Je suis passionné de musique  et de '
#                         'philosophie.',
#           'host_has_profile_pic': True,
#           'host_id': '49258343',
#           'host_identity_verified': False,
#           'host_is_superhost': False,
#           'host_listings_count': 1,
#           'host_location': 'Montreal, Québec, Canada',
#           'host_name': 'Xavier Neszvecsko',
#           'host_neighbourhood': 'La Petite-Patrie',
#           'host_picture_url': 'https://a0.muscache.com/im/pictures/user/072fc2dd-b6b7-40bc-a6dc-e7ae2b599869.jpg?aki_policy=profile_x_medium',
#           'host_response_rate': 83,
#           'host_response_time': 'within a few hours',
#           'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/user/072fc2dd-b6b7-40bc-a6dc-e7ae2b599869.jpg?aki_policy=profile_small',
#           'host_total_listings_count': 1,
#           'host_url': 'https://www.airbnb.com/users/show/49258343',
#           'host_verifications': ['email',
#                                  'phone',
#                                  'google',
#                                  'reviews',
#                                  'jumio',
#                                  'government_id']},
#  'house_rules': 'Les voyageurs doivent : - faire leur propre vaisselle et la '
#                 'placer dans le séchoir.  - enlever leurs chaussures à '
#                 "l'intérieur  - être propres et responsables de leur personne "
#                 'en général',
#  'images': {'medium_url': '',
#             'picture_url': 'https://a0.muscache.com/im/pictures/0bc52b9b-f357-442f-924a-e69e2fa2d753.jpg?aki_policy=large',
#             'thumbnail_url': '',
#             'xl_picture_url': ''},
#  'interaction': 'I will be happy to help the traveler if I have the time and '
#                 'the necessary knowledge. However, I am a solitary and '
#                 'independent person and I appreciate that the travelers '
#                 'present are autonomous and mature. Violence of any sort will '
#                 'not be tolerated in this space. This includes: verbal '
#                 'harrassment, physical violence, sexual assault, violations of '
#                 'consent, homophobia, transphobia, racism, and sexism.',
#  'last_review': datetime.datetime(2018, 11, 1, 4, 0),
#  'last_scraped': datetime.datetime(2019, 3, 11, 4, 0),
#  'listing_url': 'https://www.airbnb.com/rooms/9505003',
#  'maximum_nights': '1125',
#  'minimum_nights': '1',
#  'name': 'Private & luminous room',
#  'neighborhood_overview': 'Rosemont La Petite-Patrie is a peaceful '
#                           'neighborhood located not far from the bustling '
#                           'summer activity areas of Montreal! Nearby you will '
#                           'find parks, cafes, bars and theaters, in addition '
#                           'to the famous Jean-Talon market where fresh fruit '
#                           'and vegetables grown in the region are offered.',
#  'notes': 'We try to always keep everything clean and ordered. We expect the '
#           'same from our visitors. However, we take care of cleaning the '
#           'bathroom, cleaning the floors. Travelers must: - make their own '
#           'dishes and place in the dishwasher (which serves as a dryer) after '
#           'their meal. - Leave all surfaces clean after use (tables, counters, '
#           'oven, etc.) - take off their shoes inside - to be clean and '
#           'responsible for their person in general - (during a stay of more '
#           'than a week) participate in removing garbage, recycling and '
#           'compost, sweep the floor once in a while.',
#  'number_of_reviews': 13,
#  'price': Decimal128('30.00'),
#  'property_type': 'Apartment',
#  'review_scores': {'review_scores_accuracy': 10,
#                    'review_scores_checkin': 10,
#                    'review_scores_cleanliness': 10,
#                    'review_scores_communication': 10,
#                    'review_scores_location': 10,
#                    'review_scores_rating': 100,
#                    'review_scores_value': 10},
#  'reviews': [{'_id': '82262422',
#               'comments': 'Merci Xavier ! Je suis arrivé très tard la nuit '
#                           "après un contrat et l'endroit était exactement "
#                           "comme Xavier me l'avait communiqué. Quartier très "
#                           'tranquille mais pas loin du centre actif de la '
#                           "ville. J'ai aimé les grands arbres de la rue, plein "
#                           "d'oiseaux, la piste cyclable. Le lendemain matin "
#                           "j'ai vraiment apprécié le secteur, le choix était "
#                           "là pour les cafés et j'ai finalement pris le temps "
#                           "d'aller découvrir le coloré Marché Jean-Talon à "
#                           "quelques coins de rues de l'appartement de Xavier. "
#                           "Merci encore et au plaisir, c'est tellement génial "
#                           "Airbnb quand on réalise que c'est si simple être "
#                           "hébergé chez des gens accueillants plutôt qu'au "
#                           'centre-ville bruyant :-)',
#               'date': datetime.datetime(2016, 6, 27, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '79735026',
#               'reviewer_name': 'Duane'},
#              {'_id': '83325725',
#               'comments': 'Un super séjour. Des hôtes accueillant, sympathique '
#                           'et disponible. La chambre est grande et il y a une '
#                           'belle arrière cour pour profiter du soleil. Le '
#                           'quartier est agréable et calme à proximité des '
#                           'commerces, tout y est pour passé un bon séjour ! ',
#               'date': datetime.datetime(2016, 7, 2, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '79615544',
#               'reviewer_name': 'Justin'},
#              {'_id': '171750173',
#               'comments': "Xavier's place was amazing... 5 Stars!!!\n"
#                           '\n'
#                           'Both he and Robert were amazing hosts, very '
#                           'friendly and a lot of fun to talk too.\n'
#                           '\n'
#                           'The house is beautiful and in a great location. It '
#                           'was so convienent, with many great coffee shops and '
#                           'restaurants all walking distance. The train station '
#                           'is also close by too, so very easy to get around '
#                           'the city.\n'
#                           '\n'
#                           'I will definitely be coming back to stay there '
#                           'again when I return to Montreal :) \n'
#                           '\n'
#                           "Their home has been one of my favorite places I've "
#                           'stayed at so far!\n'
#                           '\n'
#                           "I would highly recommend Xavier's place to all "
#                           'travelers.',
#               'date': datetime.datetime(2017, 7, 18, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '7329263',
#               'reviewer_name': 'Imran'},
#              {'_id': '188202383',
#               'comments': 'I spent close to a month in this beautiful '
#                           'apartment, where I enjoyed all of its bright and '
#                           'quiet spaces. The neighborhood is tree-lined and '
#                           'largely residential, but bordered by main streets '
#                           'that are full of hang out spots and whatever food '
#                           'wants or needs one might have. The apartment is '
#                           'within walking distance from many nice parts and '
#                           'parks of Montreal, and accessible by public '
#                           'transportation if one wants to go a bit further. \n'
#                           '\n'
#                           'Xavier and Robert were really lovely and '
#                           'hospitable, and it was a pleasure to share the '
#                           'apartment with them and their beautiful dog '
#                           'Juliette.',
#               'date': datetime.datetime(2017, 8, 28, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '1752950',
#               'reviewer_name': 'Maysam'},
#              {'_id': '205676811',
#               'comments': "Xavier's place is on a quiet side street but close "
#                           'to many interesting sights: Little Italy, the Jean '
#                           'Talon market, lots of small restaurants and cafes, '
#                           'easy access to the orange metro line. \n'
#                           'The room is bright and spacious, and decorated in '
#                           'retro style with many little touches (as is the '
#                           'rest of the apartment). Really nice semi-closed '
#                           'patio on the back. Excellent value overall! If you '
#                           'like dogs, even better, Juliette is an angel and '
#                           'will let you rub her belly.\n'
#                           'Xavier was a great host, he welcomed me warmly and '
#                           'was very helpful in giving me advice on settling '
#                           'down in Montreal. He was respectful and discreet, '
#                           "but didn't hesitate to share a beer and a chat with "
#                           'me. Highly recommended!',
#               'date': datetime.datetime(2017, 10, 22, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '24027877',
#               'reviewer_name': 'Francesca'},
#              {'_id': '267472190',
#               'comments': "J'ai d'abord été accueilli par la maitresse des "
#                           "lieux, la belle et paisible Juliette, ensuite j'ai "
#                           "pu rencontrer Xavier et Robert qui m'ont tout deux "
#                           "permis de passer d'excellents moments en leur "
#                           'compagnie.\n'
#                           'La maison est très spacieuse avec une cours à '
#                           'l’arrière parfaite pour "chiller" et travailler au '
#                           'soleil.\n'
#                           'Merci pour ces 10 jours\n'
#                           'Cordialement',
#               'date': datetime.datetime(2018, 5, 21, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '27521329',
#               'reviewer_name': 'Laurent'},
#              {'_id': '272465787',
#               'comments': 'Spacious place to stay and work, I especially '
#                           'enjoyed the patio and backyard - there are so many '
#                           'tables ;) Xavier and Robert are both very friendly '
#                           'and helpful. They are open to share the space and '
#                           'willing to give local tips. La Petite Patrie is a '
#                           'safe, quiet, and convenient neighborhood with '
#                           'access to buses and metro, groceries, cafes and '
#                           'restos. I hope to stay at Xavier’s the next time '
#                           'I’m in the city.',
#               'date': datetime.datetime(2018, 6, 3, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '32804986',
#               'reviewer_name': 'Daniel'},
#              {'_id': '274570927',
#               'comments': 'Appartement très bien situé. Chambre spacieuse et '
#                           'confortable.',
#               'date': datetime.datetime(2018, 6, 9, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '2608203',
#               'reviewer_name': 'Marie & Flaco'},
#              {'_id': '284422971',
#               'comments': 'J’ai passé un très agréable séjour de 2,5 semaines '
#                           'chez Xavier. L’appartement est propre, lumineux, '
#                           'plein de charme, typique de Montréal, très calme et '
#                           "entouré d'arbres. La chambre est très spacieuse et "
#                           'bien décorée, paisible et le lit confortable. Une '
#                           'grande véranda donne sur le jardin. L’appartement '
#                           'est situé près du métro Beaubien, de la rue St '
#                           'Hubert et du marché Jean Talon, à proximité de '
#                           'nombreux commerces et restaurants. \n'
#                           'Xavier et Robert sont des hôtes '
#                           'accueillants,chaleureux et respectueux avec qui '
#                           "j'ai eu des discussions très intéressantes. J’y "
#                           'retournerai avec joie et recommanderai sans réserve '
#                           'ce logement à mes amis.',
#               'date': datetime.datetime(2018, 7, 1, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '136387788',
#               'reviewer_name': 'Corinne'},
#              {'_id': '301644847',
#               'comments': 'Fiquei no espaço do Xavier e do Robert por 1 mês.\n'
#                           'Eles foram muito simpáticos e hospitaleiros desde o '
#                           'início. A casa é muito grande e conta com um ótimo '
#                           'jardim. É localizado em um bairro muito simpático '
#                           'com fácil acesso ao metro, ônibus, mercearias, '
#                           'cafés, parques, cinemas...\n'
#                           'O quarto é muito grande, bem iluminado e '
#                           'confortável.\n'
#                           '\n'
#                           'Obrigado pela acolhida, Robert e Xavier. Até a '
#                           'próxima',
#               'date': datetime.datetime(2018, 8, 4, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '110613449',
#               'reviewer_name': 'Othello'},
#              {'_id': '309681717',
#               'comments': 'Xavier is a thoughtful and friendly host. The room '
#                           'and shared spaces are clean and the home is in a '
#                           'great part of town. I felt comfortable and welcome '
#                           "during my entire stay. Don't hesitate to stay with "
#                           'Xavier :-)',
#               'date': datetime.datetime(2018, 8, 18, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '18699348',
#               'reviewer_name': 'Christian'},
#              {'_id': '330512677',
#               'comments': 'Chez Xavier était sympa et tranquille. J’aimais le '
#                           'quartier, proche du supermarché, la station du '
#                           'métro et le marché Jean Talon.',
#               'date': datetime.datetime(2018, 9, 30, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '4336141',
#               'reviewer_name': 'Hamish'},
#              {'_id': '343711271',
#               'comments': 'I had a short but excellent stay at Xavier’s place. '
#                           'It’s unique decor is good for relaxing. And it’s in '
#                           'a very nice and peaceful area.\n'
#                           'It was great interacting with Xavier who is full of '
#                           'creative talents. And Juliette was affable as well.',
#               'date': datetime.datetime(2018, 11, 1, 4, 0),
#               'listing_id': '9505003',
#               'reviewer_id': '167576772',
#               'reviewer_name': 'Deepak'}],
#  'room_type': 'Private room',
#  'security_deposit': Decimal128('300.00'),
#  'space': 'Currently, the house is occupied by Xavier, Jessica and Juliet (my '
#           'dog). Jessica is completing her MA in Political History; she '
#           'advocates for progressive causes and is also interested in the arts '
#           'and the circus. You can look at my profile to learn more about me. '
#           'Juliette is a truly dog angel (very calm and affectionate)! Thank '
#           'you for writing a detailed and personalized request to give us an '
#           'idea of what kind of person and roommate you are.',
#  'summary': 'Beautiful and luminous room in Rosemont Petite Patrie! The '
#             'apartment has three bedrooms (mine, yours and another for '
#             'travelers), plus a bureau, a kitchen, a semi-finished basement, a '
#             'veranda and a large backyard to which you have access! You can '
#             'find anything you want in the neighboorhood from parc, cafes, '
#             'bars, grocery stores, etc. You have access to two metro within 10 '
#             'minute walk and the cycle path is right is passing right in front '
#             'of the appartment. We look forward to welcoming you!',
#  'transit': 'Parking on the adjoining street, public transport everywhere '
#             'around, whether bus or metro!'}

# %% [markdown]
# -> Qual é a escalda das review_scores? porque porque parecem estar todas de 0 a 10 mas a review_cores_rating está de 0 a 100 acho então fazer a average das review_scores n faz sentido

# %% [markdown]
# ### Question 10 - We aim to have better access to information about transaction, we wish to develop a search engine that can calculate the average value of transactions in a given period of time quickly for a given property.

# %% [markdown]
# ### Question 11

# %% [markdown]
# ### Question 12

# %% [markdown]
# ### Question 13

# %% [markdown]
# ### Question 14
